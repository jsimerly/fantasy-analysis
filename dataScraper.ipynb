# %%
import pandas as pd
from bs4 import BeautifulSoup
import pickle
import time
import random
from dotenv import load_dotenv
import os
import requests
import re

from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

from models import Player, Game, QbGameStats, SkillGameStats

# %%
def get_page(url):
    resp = requests.get(url)
    return resp
    
def get_soup(resp):
    soup = BeautifulSoup(resp.text, 'html.parser')
    return soup

def request_soup(url):
    resp = get_page(url)
    return get_soup(resp)

def extract_number(text):
    match = re.search(r'\d+', text)
    if match:
        return int(match.group())
    else:
        return None

# %%
#load hrefs
with open('player_hrefs.pkl', 'rb') as f:
    player_hrefs  = pickle.load(f)
# Out:
# 1154

# %%
soup = request_soup('https://pro-football-reference.com/players/B/BradTo00/gamelog')

# %%
player_info = soup.find('div', {'id':'info'})
player_data = {}

player_data['name'] = player_info.find('h1').text.strip()

p_tags = player_info.find_all('p')

#position
pos_tag = player_info.find('strong', string='Position')
if pos_tag:
    pos = pos_tag.find_next_sibling(string=True)
    if next_text:
        player_data['name'] = pos.strip(": ").strip()

#Dimensions
dim_str = p_tags[2].text
cm_start = dim_str.find('(') + 1
cm_end = dim_str.find('c')
kg_start = cm_end + 4
kg_end = dim_str.find("k")

cm_str = dim_str[cm_start:cm_end]
kg_str = dim_str[kg_start:kg_end]

player_data['height_cm'] = int(cm_str)
player_data['weight_kg'] = int(kg_str)

#Date of Birth
bday_start_index = str(p_tags[3]).find('data-birth=') + len('data-birth=') + 1
bday_end_index = bday_start_index + 10
bday_str = str(p_tags[3])[bday_start_index : bday_end_index]
player_data['dob'] = bday_str

#College
player_data['college'] = p_tags[4].find('a').text.strip()

#drafted
overall_start_index = p_tags[7].text.find("(") + 1
overall_end_index = p_tags[7].text.find(")")
overall_str = p_tags[7].text[overall_start_index:overall_end_index]
player_data['drafted_overall'] = extract_number(overall_str)

player_data['drafted_year'] = None
if player_data['drafted_overall']:
    year_str = p_tags[7].text[overall_end_index:]
    try:
        player_data['drafted_year'] = extract_number(year_str)
    except:
        print(f"Issue with drafted year for {player_data['name']}")     

player_data
# Out:
# {'name': 'QB',
#  'height_cm': 193,
#  'weight_kg': 102,
#  'dob': '1977-08-03',
#  'college': 'Michigan',
#  'drafted_overall': 199,
#  'drafted_year': 2000}

# %%
table = soup.find('table', {'class': 'stats_table'}).find('tbody')
stats_tables = table.findAll('tr', {'id': re.compile("^stats")})
dnps = table.findAll('tr', {'id': re.compile("^injury")})

player_game_data = []
for data in stats_tables:
    game_stats = {}
    game_stats['year'] = data.find('td', {"data-stat" : "year_id"}).text
    game_stats['date'] = data.find('td', {"data-stat" : "game_date"}).text
    game_stats['week'] = data.find('td', {"data-stat" : "week_num"}).text
    game_stats['age'] = data.find('td', {"data-stat" : "age"}).text
    game_stats['team'] = data.find('td', {"data-stat" : "team"}).text
    game_stats['away_game'] = data.find('td', {"data-stat": "game_location"}).text.strip() == '@'
    game_stats['opp'] = data.find('td', {"data-stat" : "opp"}).text
    game_stats['started'] = data.find('td', {"data-stat" : "gs"}).text
    game_stats['pass_comp'] = data.find('td', {"data-stat" : "pass_cmp"}).text
    game_stats['pass_att'] = data.find('td', {"data-stat" : "pass_att"}).text
    game_stats['pass_cmp_perc'] = data.find('td', {"data-stat" : "pass_cmp_perc"}).text
    game_stats['pass_yds'] = data.find('td', {"data-stat" : "pass_yds"}).text
    game_stats['pass_td'] = data.find('td', {"data-stat" : "pass_td"}).text
    game_stats['pass_int'] = data.find('td', {"data-stat" : "pass_int"}).text
    game_stats['pass_sacked'] = data.find('td', {"data-stat" : "pass_sacked"}).text
    game_stats['pass_yds_per_att'] = data.find('td', {"data-stat" : "pass_yds_per_att"}).text
    game_stats['pass_adj_yds_per_att'] = data.find('td', {"data-stat" : "pass_adj_yds_per_att"}).text
    
    game_stats['rush_att'] = data.find('td', {"data-stat" : "rush_att"}).text
    game_stats['rush_yds'] = data.find('td', {"data-stat" : "rush_yds"}).text
    game_stats['rush_td'] = data.find('td', {"data-stat" : "rush_td"}).text
    
    game_stats['fumbles'] = data.find('td', {"data-stat" : "fumbles"}).text

    player_game_data.append(game_stats)

# %%
for href in player_hrefs:
    player_url = f'pro-football-reference.com{href}'
    print(player_url)
# Out:
# pro-football-reference.com/players/A/AndeMi00.htm
# pro-football-reference.com/players/G/GoedDa00.htm
# pro-football-reference.com/players/H/HarbJi00.htm
# pro-football-reference.com/players/T/ThomCh03.htm
# pro-football-reference.com/players/W/WarrPe00.htm
# pro-football-reference.com/players/L/LemoCl00.htm
# pro-football-reference.com/players/W/WashNa00.htm
# pro-football-reference.com/players/D/DarkOr00.htm
# pro-football-reference.com/players/S/SlatSt00.htm
# pro-football-reference.com/players/M/MossRa00.htm
# pro-football-reference.com/players/B/BrowMa03.htm
# pro-football-reference.com/players/K/KeenCa00.htm
# pro-football-reference.com/players/S/SandAc00.htm
# pro-football-reference.com/players/M/McElGr00.htm
# pro-football-reference.com/players/P/PalmJo00.htm
# pro-football-reference.com/players/G/GageJu00.htm
# pro-football-reference.com/players/J/JohnBr02.htm
# pro-football-reference.com/players/C/CassMa00.htm
# pro-football-reference.com/players/F/FishTo00.htm
# pro-football-reference.com/players/J/JackBr00.htm
# pro-football-reference.com/players/M/MasoDe00.htm
# pro-football-reference.com/players/M/MossZa00.htm
# pro-football-reference.com/players/J/JohnDa08.htm
# pro-football-reference.com/players/S/SuttCo00.htm
# pro-football-reference.com/players/J/JohnJu02.htm
# pro-football-reference.com/players/S/SmitRo00.htm
# pro-football-reference.com/players/M/McKnJa00.htm
# pro-football-reference.com/players/A/AverDo00.htm
# pro-football-reference.com/players/C/CrowJa00.htm
# pro-football-reference.com/players/H/HillTa00.htm
# pro-football-reference.com/players/P/PeteAd01.htm
# pro-football-reference.com/players/S/SmitOn00.htm
# pro-football-reference.com/players/P/PondCh00.htm
# pro-football-reference.com/players/H/HendDa00.htm
# pro-football-reference.com/players/H/HogaCh00.htm
# pro-football-reference.com/players/C/ChubNi00.htm
# pro-football-reference.com/players/H/HeluRo00.htm
# pro-football-reference.com/players/W/WilsGa00.htm
# pro-football-reference.com/players/L/LaFeBr00.htm
#   'week': '13',
#   'age': '23.112',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'DET',
#   'started': '',
#   'pass_comp': '1',
#   'pass_att': '3',
#   'pass_cmp_perc': '33.33',
#   'pass_yds': '6',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '2.00',
#   'pass_adj_yds_per_att': '2.00',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-09-23',
#   'week': '2',
#   'age': '24.051',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NYJ',
#   'started': '',
#   'pass_comp': '5',
#   'pass_att': '10',
#   'pass_cmp_perc': '50.00',
#   'pass_yds': '46',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '4.60',
#   'pass_adj_yds_per_att': '4.60',
#   'rush_att': '1',
#   'rush_yds': '9',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-09-30',
#   'week': '3',
#   'age': '24.058',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '13',
#   'pass_att': '23',
#   'pass_cmp_perc': '56.52',
#   'pass_yds': '168',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.30',
#   'pass_adj_yds_per_att': '7.30',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-10-07',
#   'week': '4',
#   'age': '24.065',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '12',
#   'pass_att': '24',
#   'pass_cmp_perc': '50.00',
#   'pass_yds': '86',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '3.58',
#   'pass_adj_yds_per_att': '3.58',
#   'rush_att': '2',
#   'rush_yds': '9',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2001',
#   'date': '2001-10-14',
#   'week': '5',
#   'age': '24.072',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'SDG',
#   'started': '*',
#   'pass_comp': '33',
#   'pass_att': '54',
#   'pass_cmp_perc': '61.11',
#   'pass_yds': '364',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '6.74',
#   'pass_adj_yds_per_att': '7.48',
#   'rush_att': '1',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2001',
#   'date': '2001-10-21',
#   'week': '6',
#   'age': '24.079',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '16',
#   'pass_att': '20',
#   'pass_cmp_perc': '80.00',
#   'pass_yds': '202',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '10.10',
#   'pass_adj_yds_per_att': '13.10',
#   'rush_att': '2',
#   'rush_yds': '-2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-10-28',
#   'week': '7',
#   'age': '24.086',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'DEN',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '38',
#   'pass_cmp_perc': '65.79',
#   'pass_yds': '203',
#   'pass_td': '2',
#   'pass_int': '4',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '5.34',
#   'pass_adj_yds_per_att': '1.66',
#   'rush_att': '2',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2001',
#   'date': '2001-11-04',
#   'week': '8',
#   'age': '24.093',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'ATL',
#   'started': '*',
#   'pass_comp': '21',
#   'pass_att': '31',
#   'pass_cmp_perc': '67.74',
#   'pass_yds': '250',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '8.06',
#   'pass_adj_yds_per_att': '10.00',
#   'rush_att': '3',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-11-11',
#   'week': '9',
#   'age': '24.100',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '21',
#   'pass_cmp_perc': '71.43',
#   'pass_yds': '107',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '7',
#   'pass_yds_per_att': '5.10',
#   'pass_adj_yds_per_att': '3.90',
#   'rush_att': '4',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2001',
#   'date': '2001-11-18',
#   'week': '10',
#   'age': '24.107',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'STL',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '27',
#   'pass_cmp_perc': '70.37',
#   'pass_yds': '185',
#   'pass_td': '1',
#   'pass_int': '2',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.85',
#   'pass_adj_yds_per_att': '4.26',
#   'rush_att': '2',
#   'rush_yds': '6',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-11-25',
#   'week': '11',
#   'age': '24.114',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NOR',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '26',
#   'pass_cmp_perc': '73.08',
#   'pass_yds': '258',
#   'pass_td': '4',
#   'pass_int': '0',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '9.92',
#   'pass_adj_yds_per_att': '13.00',
#   'rush_att': '4',
#   'rush_yds': '14',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2001',
#   'date': '2001-12-02',
#   'week': '12',
#   'age': '24.121',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '28',
#   'pass_cmp_perc': '71.43',
#   'pass_yds': '213',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.61',
#   'pass_adj_yds_per_att': '7.61',
#   'rush_att': '3',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2001',
#   'date': '2001-12-09',
#   'week': '13',
#   'age': '24.128',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'CLE',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '28',
#   'pass_cmp_perc': '67.86',
#   'pass_yds': '218',
#   'pass_td': '0',
#   'pass_int': '2',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.79',
#   'pass_adj_yds_per_att': '4.57',
#   'rush_att': '4',
#   'rush_yds': '-3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-12-16',
#   'week': '14',
#   'age': '24.135',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '35',
#   'pass_cmp_perc': '54.29',
#   'pass_yds': '237',
#   'pass_td': '0',
#   'pass_int': '1',
#   'pass_sacked': '5',
#   'pass_yds_per_att': '6.77',
#   'pass_adj_yds_per_att': '5.49',
#   'rush_att': '3',
#   'rush_yds': '13',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2001',
#   'date': '2001-12-22',
#   'week': '15',
#   'age': '24.141',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '11',
#   'pass_att': '19',
#   'pass_cmp_perc': '57.89',
#   'pass_yds': '108',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '5.68',
#   'pass_adj_yds_per_att': '6.74',
#   'rush_att': '3',
#   'rush_yds': '-5',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2001',
#   'date': '2002-01-06',
#   'week': '17',
#   'age': '24.156',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'CAR',
#   'started': '*',
#   'pass_comp': '17',
#   'pass_att': '29',
#   'pass_cmp_perc': '58.62',
#   'pass_yds': '198',
#   'pass_td': '1',
#   'pass_int': '2',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '6.83',
#   'pass_adj_yds_per_att': '4.41',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2002',
#   'date': '2002-09-09',
#   'week': '1',
#   'age': '25.037',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'PIT',
#   'started': '*',
#   'pass_comp': '29',
#   'pass_att': '43',
#   'pass_cmp_perc': '67.44',
#   'pass_yds': '294',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.84',
#   'pass_adj_yds_per_att': '8.23',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-09-15',
#   'week': '2',
#   'age': '25.043',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '35',
#   'pass_cmp_perc': '71.43',
#   'pass_yds': '269',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.69',
#   'pass_adj_yds_per_att': '7.54',
#   'rush_att': '2',
#   'rush_yds': '5',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-09-22',
#   'week': '3',
#   'age': '25.050',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'KAN',
#   'started': '*',
#   'pass_comp': '39',
#   'pass_att': '54',
#   'pass_cmp_perc': '72.22',
#   'pass_yds': '410',
#   'pass_td': '4',
#   'pass_int': '1',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '7.59',
#   'pass_adj_yds_per_att': '8.24',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2002',
#   'date': '2002-09-29',
#   'week': '4',
#   'age': '25.057',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'SDG',
#   'started': '*',
#   'pass_comp': '36',
#   'pass_att': '53',
#   'pass_cmp_perc': '67.92',
#   'pass_yds': '353',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '6.66',
#   'pass_adj_yds_per_att': '5.72',
#   'rush_att': '1',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-10-06',
#   'week': '5',
#   'age': '25.064',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '17',
#   'pass_att': '31',
#   'pass_cmp_perc': '54.84',
#   'pass_yds': '240',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.74',
#   'pass_adj_yds_per_att': '6.13',
#   'rush_att': '1',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2002',
#   'date': '2002-10-13',
#   'week': '6',
#   'age': '25.071',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'GNB',
#   'started': '*',
#   'pass_comp': '24',
#   'pass_att': '44',
#   'pass_cmp_perc': '54.55',
#   'pass_yds': '183',
#   'pass_td': '1',
#   'pass_int': '3',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '4.16',
#   'pass_adj_yds_per_att': '1.55',
#   'rush_att': '5',
#   'rush_yds': '26',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2002',
#   'date': '2002-10-27',
#   'week': '8',
#   'age': '25.085',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'DEN',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '29',
#   'pass_cmp_perc': '51.72',
#   'pass_yds': '130',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '5',
#   'pass_yds_per_att': '4.48',
#   'pass_adj_yds_per_att': '5.17',
#   'rush_att': '2',
#   'rush_yds': '5',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-11-03',
#   'week': '9',
#   'age': '25.092',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '26',
#   'pass_cmp_perc': '84.62',
#   'pass_yds': '265',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '10.19',
#   'pass_adj_yds_per_att': '12.50',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-11-10',
#   'week': '10',
#   'age': '25.099',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'CHI',
#   'started': '*',
#   'pass_comp': '36',
#   'pass_att': '55',
#   'pass_cmp_perc': '65.45',
#   'pass_yds': '328',
#   'pass_td': '3',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '5.96',
#   'pass_adj_yds_per_att': '6.24',
#   'rush_att': '3',
#   'rush_yds': '16',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2002',
#   'date': '2002-11-17',
#   'week': '11',
#   'age': '25.106',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'OAK',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '30',
#   'pass_cmp_perc': '60.00',
#   'pass_yds': '172',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '5.73',
#   'pass_adj_yds_per_att': '5.73',
#   'rush_att': '1',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2002',
#   'date': '2002-11-24',
#   'week': '12',
#   'age': '25.113',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'MIN',
#   'started': '*',
#   'pass_comp': '21',
#   'pass_att': '34',
#   'pass_cmp_perc': '61.76',
#   'pass_yds': '239',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.03',
#   'pass_adj_yds_per_att': '8.79',
#   'rush_att': '6',
#   'rush_yds': '4',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2002',
#   'date': '2002-11-28',
#   'week': '13',
#   'age': '25.117',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'DET',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '30',
#   'pass_cmp_perc': '60.00',
#   'pass_yds': '210',
#   'pass_td': '0',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.00',
#   'pass_adj_yds_per_att': '5.50',
#   'rush_att': '4',
#   'rush_yds': '12',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-12-08',
#   'week': '14',
#   'age': '25.127',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '27',
#   'pass_cmp_perc': '55.56',
#   'pass_yds': '183',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '6.78',
#   'pass_adj_yds_per_att': '8.26',
#   'rush_att': '5',
#   'rush_yds': '-5',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2002',
#   'date': '2002-12-16',
#   'week': '15',
#   'age': '25.135',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'TEN',
#   'started': '*',
#   'pass_comp': '14',
#   'pass_att': '29',
#   'pass_cmp_perc': '48.28',
#   'pass_yds': '134',
#   'pass_td': '0',
#   'pass_int': '1',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '4.62',
#   'pass_adj_yds_per_att': '3.07',
#   'rush_att': '2',
#   'rush_yds': '10',
#   'rush_td': '1',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-12-22',
#   'week': '16',
#   'age': '25.141',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '37',
#   'pass_cmp_perc': '51.35',
#   'pass_yds': '133',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '3.59',
#   'pass_adj_yds_per_att': '2.92',
#   'rush_att': '4',
#   'rush_yds': '24',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2002',
#   'date': '2002-12-29',
#   'week': '17',
#   'age': '25.148',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '44',
#   'pass_cmp_perc': '56.82',
#   'pass_yds': '221',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '5.02',
#   'pass_adj_yds_per_att': '4.45',
#   'rush_att': '4',
#   'rush_yds': '8',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2003',
#   'date': '2003-09-07',
#   'week': '1',
#   'age': '26.035',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '14',
#   'pass_att': '28',
#   'pass_cmp_perc': '50.00',
#   'pass_yds': '123',
#   'pass_td': '0',
#   'pass_int': '4',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '4.39',
#   'pass_adj_yds_per_att': '-2.04',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-09-14',
#   'week': '2',
#   'age': '26.042',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'PHI',
#   'started': '*',
#   'pass_comp': '30',
#   'pass_att': '44',
#   'pass_cmp_perc': '68.18',
#   'pass_yds': '255',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '5.80',
#   'pass_adj_yds_per_att': '7.16',
#   'rush_att': '6',
#   'rush_yds': '7',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-09-21',
#   'week': '3',
#   'age': '26.049',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '25',
#   'pass_cmp_perc': '60.00',
#   'pass_yds': '181',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '5',
#   'pass_yds_per_att': '7.24',
#   'pass_adj_yds_per_att': '7.24',
#   'rush_att': '3',
#   'rush_yds': '-1',
#   'rush_td': '1',
#   'fumbles': '3'},
#  {'year': '2003',
#   'date': '2003-09-28',
#   'week': '4',
#   'age': '26.056',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'WAS',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '38',
#   'pass_cmp_perc': '65.79',
#   'pass_yds': '289',
#   'pass_td': '2',
#   'pass_int': '3',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.61',
#   'pass_adj_yds_per_att': '5.11',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-10-05',
#   'week': '5',
#   'age': '26.063',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'TEN',
#   'started': '*',
#   'pass_comp': '17',
#   'pass_att': '31',
#   'pass_cmp_perc': '54.84',
#   'pass_yds': '219',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.06',
#   'pass_adj_yds_per_att': '7.71',
#   'rush_att': '3',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2003',
#   'date': '2003-10-12',
#   'week': '6',
#   'age': '26.070',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NYG',
#   'started': '*',
#   'pass_comp': '8',
#   'pass_att': '21',
#   'pass_cmp_perc': '38.10',
#   'pass_yds': '112',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '5.33',
#   'pass_adj_yds_per_att': '5.33',
#   'rush_att': '3',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-10-19',
#   'week': '7',
#   'age': '26.077',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '24',
#   'pass_att': '34',
#   'pass_cmp_perc': '70.59',
#   'pass_yds': '283',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.32',
#   'pass_adj_yds_per_att': '9.50',
#   'rush_att': '3',
#   'rush_yds': '10',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2003',
#   'date': '2003-10-26',
#   'week': '8',
#   'age': '26.084',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'CLE',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '33',
#   'pass_cmp_perc': '60.61',
#   'pass_yds': '259',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.85',
#   'pass_adj_yds_per_att': '7.85',
#   'rush_att': '2',
#   'rush_yds': '-2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-11-03',
#   'week': '9',
#   'age': '26.092',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'DEN',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '35',
#   'pass_cmp_perc': '57.14',
#   'pass_yds': '350',
#   'pass_td': '3',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '10.00',
#   'pass_adj_yds_per_att': '10.43',
#   'rush_att': '2',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2003',
#   'date': '2003-11-16',
#   'week': '11',
#   'age': '26.105',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'DAL',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '34',
#   'pass_cmp_perc': '44.12',
#   'pass_yds': '212',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.24',
#   'pass_adj_yds_per_att': '6.24',
#   'rush_att': '1',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2003',
#   'date': '2003-11-23',
#   'week': '12',
#   'age': '26.112',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'HOU',
#   'started': '*',
#   'pass_comp': '29',
#   'pass_att': '47',
#   'pass_cmp_perc': '61.70',
#   'pass_yds': '368',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '7.83',
#   'pass_adj_yds_per_att': '6.77',
#   'rush_att': '6',
#   'rush_yds': '15',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2003',
#   'date': '2003-11-30',
#   'week': '13',
#   'age': '26.119',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '26',
#   'pass_att': '35',
#   'pass_cmp_perc': '74.29',
#   'pass_yds': '236',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.74',
#   'pass_adj_yds_per_att': '5.31',
#   'rush_att': '2',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2003',
#   'date': '2003-12-07',
#   'week': '14',
#   'age': '26.126',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '16',
#   'pass_att': '31',
#   'pass_cmp_perc': '51.61',
#   'pass_yds': '163',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '5.26',
#   'pass_adj_yds_per_att': '5.26',
#   'rush_att': '2',
#   'rush_yds': '-2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-12-14',
#   'week': '15',
#   'age': '26.133',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'JAX',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '34',
#   'pass_cmp_perc': '64.71',
#   'pass_yds': '228',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.71',
#   'pass_adj_yds_per_att': '7.88',
#   'rush_att': '1',
#   'rush_yds': '7',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-12-20',
#   'week': '16',
#   'age': '26.139',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '25',
#   'pass_cmp_perc': '60.00',
#   'pass_yds': '138',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '5.52',
#   'pass_adj_yds_per_att': '7.12',
#   'rush_att': '2',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2003',
#   'date': '2003-12-27',
#   'week': '17',
#   'age': '26.146',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '21',
#   'pass_att': '32',
#   'pass_cmp_perc': '65.63',
#   'pass_yds': '204',
#   'pass_td': '4',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.38',
#   'pass_adj_yds_per_att': '8.88',
#   'rush_att': '5',
#   'rush_yds': '23',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2004',
#   'date': '2004-09-09',
#   'week': '1',
#   'age': '27.037',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '26',
#   'pass_att': '38',
#   'pass_cmp_perc': '68.42',
#   'pass_yds': '335',
#   'pass_td': '3',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '8.82',
#   'pass_adj_yds_per_att': '9.21',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2004',
#   'date': '2004-09-19',
#   'week': '2',
#   'age': '27.047',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'ARI',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '26',
#   'pass_cmp_perc': '57.69',
#   'pass_yds': '219',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '8.42',
#   'pass_adj_yds_per_att': '6.50',
#   'rush_att': '5',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2004',
#   'date': '2004-10-03',
#   'week': '4',
#   'age': '27.061',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '17',
#   'pass_att': '30',
#   'pass_cmp_perc': '56.67',
#   'pass_yds': '298',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '9.93',
#   'pass_adj_yds_per_att': '11.27',
#   'rush_att': '2',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-10-10',
#   'week': '5',
#   'age': '27.068',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '7',
#   'pass_att': '19',
#   'pass_cmp_perc': '36.84',
#   'pass_yds': '76',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '4.00',
#   'pass_adj_yds_per_att': '3.74',
#   'rush_att': '4',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-10-17',
#   'week': '6',
#   'age': '27.075',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'SEA',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '30',
#   'pass_cmp_perc': '63.33',
#   'pass_yds': '231',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.70',
#   'pass_adj_yds_per_att': '6.87',
#   'rush_att': '3',
#   'rush_yds': '7',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2004',
#   'date': '2004-10-24',
#   'week': '7',
#   'age': '27.082',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '29',
#   'pass_cmp_perc': '68.97',
#   'pass_yds': '230',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.93',
#   'pass_adj_yds_per_att': '8.62',
#   'rush_att': '3',
#   'rush_yds': '-3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-10-31',
#   'week': '8',
#   'age': '27.089',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'PIT',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '43',
#   'pass_cmp_perc': '58.14',
#   'pass_yds': '271',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '6.30',
#   'pass_adj_yds_per_att': '5.14',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2004',
#   'date': '2004-11-07',
#   'week': '9',
#   'age': '27.096',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'STL',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '31',
#   'pass_cmp_perc': '58.06',
#   'pass_yds': '234',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.55',
#   'pass_adj_yds_per_att': '8.84',
#   'rush_att': '3',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2004',
#   'date': '2004-11-14',
#   'week': '10',
#   'age': '27.103',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '35',
#   'pass_cmp_perc': '54.29',
#   'pass_yds': '233',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.66',
#   'pass_adj_yds_per_att': '6.51',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-11-22',
#   'week': '11',
#   'age': '27.111',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'KAN',
#   'started': '*',
#   'pass_comp': '17',
#   'pass_att': '26',
#   'pass_cmp_perc': '65.38',
#   'pass_yds': '315',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '12.12',
#   'pass_adj_yds_per_att': '12.88',
#   'rush_att': '5',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-11-28',
#   'week': '12',
#   'age': '27.117',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BAL',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '30',
#   'pass_cmp_perc': '50.00',
#   'pass_yds': '172',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '5.73',
#   'pass_adj_yds_per_att': '5.73',
#   'rush_att': '3',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-12-05',
#   'week': '13',
#   'age': '27.124',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'CLE',
#   'started': '*',
#   'pass_comp': '11',
#   'pass_att': '20',
#   'pass_cmp_perc': '55.00',
#   'pass_yds': '157',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.85',
#   'pass_adj_yds_per_att': '6.60',
#   'rush_att': '1',
#   'rush_yds': '10',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2004',
#   'date': '2004-12-12',
#   'week': '14',
#   'age': '27.131',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'CIN',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '26',
#   'pass_cmp_perc': '69.23',
#   'pass_yds': '260',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '10.00',
#   'pass_adj_yds_per_att': '11.54',
#   'rush_att': '5',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-12-20',
#   'week': '15',
#   'age': '27.139',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '29',
#   'pass_cmp_perc': '62.07',
#   'pass_yds': '171',
#   'pass_td': '3',
#   'pass_int': '4',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '5.90',
#   'pass_adj_yds_per_att': '1.76',
#   'rush_att': '2',
#   'rush_yds': '-2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2004-12-26',
#   'week': '16',
#   'age': '27.145',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '21',
#   'pass_att': '32',
#   'pass_cmp_perc': '65.63',
#   'pass_yds': '264',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.25',
#   'pass_adj_yds_per_att': '9.50',
#   'rush_att': '4',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2004',
#   'date': '2005-01-02',
#   'week': '17',
#   'age': '27.152',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'SFO',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '30',
#   'pass_cmp_perc': '73.33',
#   'pass_yds': '226',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.53',
#   'pass_adj_yds_per_att': '7.37',
#   'rush_att': '1',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2005',
#   'date': '2005-09-08',
#   'week': '1',
#   'age': '28.036',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'OAK',
#   'started': '*',
#   'pass_comp': '24',
#   'pass_att': '38',
#   'pass_cmp_perc': '63.16',
#   'pass_yds': '306',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '8.05',
#   'pass_adj_yds_per_att': '9.11',
#   'rush_att': '3',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-09-18',
#   'week': '2',
#   'age': '28.046',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'CAR',
#   'started': '*',
#   'pass_comp': '23',
#   'pass_att': '44',
#   'pass_cmp_perc': '52.27',
#   'pass_yds': '270',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.14',
#   'pass_adj_yds_per_att': '5.57',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2005',
#   'date': '2005-09-25',
#   'week': '3',
#   'age': '28.053',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'PIT',
#   'started': '*',
#   'pass_comp': '31',
#   'pass_att': '41',
#   'pass_cmp_perc': '75.61',
#   'pass_yds': '372',
#   'pass_td': '0',
#   'pass_int': '1',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '9.07',
#   'pass_adj_yds_per_att': '7.98',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-10-02',
#   'week': '4',
#   'age': '28.060',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'SDG',
#   'started': '*',
#   'pass_comp': '19',
#   'pass_att': '32',
#   'pass_cmp_perc': '59.38',
#   'pass_yds': '224',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.00',
#   'pass_adj_yds_per_att': '6.22',
#   'rush_att': '2',
#   'rush_yds': '4',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-10-09',
#   'week': '5',
#   'age': '28.067',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'ATL',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '27',
#   'pass_cmp_perc': '81.48',
#   'pass_yds': '350',
#   'pass_td': '3',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '12.96',
#   'pass_adj_yds_per_att': '13.52',
#   'rush_att': '1',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-10-16',
#   'week': '6',
#   'age': '28.074',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'DEN',
#   'started': '*',
#   'pass_comp': '24',
#   'pass_att': '46',
#   'pass_cmp_perc': '52.17',
#   'pass_yds': '299',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '6.50',
#   'pass_adj_yds_per_att': '6.93',
#   'rush_att': '1',
#   'rush_yds': '12',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-10-30',
#   'week': '8',
#   'age': '28.088',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '14',
#   'pass_att': '21',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '199',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '9.48',
#   'pass_adj_yds_per_att': '10.43',
#   'rush_att': '1',
#   'rush_yds': '4',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2005',
#   'date': '2005-11-07',
#   'week': '9',
#   'age': '28.096',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '33',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '265',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.03',
#   'pass_adj_yds_per_att': '9.85',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2005',
#   'date': '2005-11-13',
#   'week': '10',
#   'age': '28.102',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '21',
#   'pass_att': '36',
#   'pass_cmp_perc': '58.33',
#   'pass_yds': '275',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.64',
#   'pass_adj_yds_per_att': '6.25',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-11-20',
#   'week': '11',
#   'age': '28.109',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NOR',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '29',
#   'pass_cmp_perc': '51.72',
#   'pass_yds': '222',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.66',
#   'pass_adj_yds_per_att': '9.72',
#   'rush_att': '1',
#   'rush_yds': '5',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2005',
#   'date': '2005-11-27',
#   'week': '12',
#   'age': '28.116',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'KAN',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '40',
#   'pass_cmp_perc': '55.00',
#   'pass_yds': '248',
#   'pass_td': '1',
#   'pass_int': '4',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '6.20',
#   'pass_adj_yds_per_att': '2.20',
#   'rush_att': '1',
#   'rush_yds': '15',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-12-04',
#   'week': '13',
#   'age': '28.123',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '27',
#   'pass_att': '37',
#   'pass_cmp_perc': '72.97',
#   'pass_yds': '271',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.32',
#   'pass_adj_yds_per_att': '7.32',
#   'rush_att': '4',
#   'rush_yds': '19',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-12-11',
#   'week': '14',
#   'age': '28.130',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '29',
#   'pass_att': '38',
#   'pass_cmp_perc': '76.32',
#   'pass_yds': '329',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.66',
#   'pass_adj_yds_per_att': '7.34',
#   'rush_att': '4',
#   'rush_yds': '17',
#   'rush_td': '1',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-12-17',
#   'week': '15',
#   'age': '28.136',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'TAM',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '31',
#   'pass_cmp_perc': '64.52',
#   'pass_yds': '258',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.32',
#   'pass_adj_yds_per_att': '10.26',
#   'rush_att': '3',
#   'rush_yds': '6',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2005-12-26',
#   'week': '16',
#   'age': '28.145',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '29',
#   'pass_cmp_perc': '62.07',
#   'pass_yds': '185',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '6.38',
#   'pass_adj_yds_per_att': '6.21',
#   'rush_att': '3',
#   'rush_yds': '7',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2005',
#   'date': '2006-01-01',
#   'week': '17',
#   'age': '28.151',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '3',
#   'pass_att': '8',
#   'pass_cmp_perc': '37.50',
#   'pass_yds': '37',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '4.63',
#   'pass_adj_yds_per_att': '1.50',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2006',
#   'date': '2006-09-10',
#   'week': '1',
#   'age': '29.038',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '11',
#   'pass_att': '23',
#   'pass_cmp_perc': '47.83',
#   'pass_yds': '163',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.09',
#   'pass_adj_yds_per_att': '6.87',
#   'rush_att': '5',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2006',
#   'date': '2006-09-17',
#   'week': '2',
#   'age': '29.045',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '29',
#   'pass_cmp_perc': '51.72',
#   'pass_yds': '220',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.59',
#   'pass_adj_yds_per_att': '6.72',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2006',
#   'date': '2006-09-24',
#   'week': '3',
#   'age': '29.052',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'DEN',
#   'started': '*',
#   'pass_comp': '31',
#   'pass_att': '55',
#   'pass_cmp_perc': '56.36',
#   'pass_yds': '320',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '5.82',
#   'pass_adj_yds_per_att': '6.18',
#   'rush_att': '2',
#   'rush_yds': '7',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2006',
#   'date': '2006-10-01',
#   'week': '4',
#   'age': '29.059',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'CIN',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '26',
#   'pass_cmp_perc': '57.69',
#   'pass_yds': '188',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.23',
#   'pass_adj_yds_per_att': '7.04',
#   'rush_att': '2',
#   'rush_yds': '21',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2006',
#   'date': '2006-10-08',
#   'week': '5',
#   'age': '29.066',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '16',
#   'pass_att': '29',
#   'pass_cmp_perc': '55.17',
#   'pass_yds': '140',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '4.83',
#   'pass_adj_yds_per_att': '6.21',
#   'rush_att': '4',
#   'rush_yds': '-3',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2006',
#   'date': '2006-10-22',
#   'week': '7',
#   'age': '29.080',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '27',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '195',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '7.22',
#   'pass_adj_yds_per_att': '8.70',
#   'rush_att': '2',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2006',
#   'date': '2006-10-30',
#   'week': '8',
#   'age': '29.088',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIN',
#   'started': '*',
#   'pass_comp': '29',
#   'pass_att': '43',
#   'pass_cmp_perc': '67.44',
#   'pass_yds': '372',
#   'pass_td': '4',
#   'pass_int': '1',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '8.65',
#   'pass_adj_yds_per_att': '9.47',
#   'rush_att': '1',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2006',
#   'date': '2006-11-05',
#   'week': '9',
#   'age': '29.094',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '35',
#   'pass_cmp_perc': '57.14',
#   'pass_yds': '201',
#   'pass_td': '0',
#   'pass_int': '4',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '5.74',
#   'pass_adj_yds_per_att': '0.60',
#   'rush_att': '3',
#   'rush_yds': '13',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2006',
#   'date': '2006-11-12',
#   'week': '10',
#   'age': '29.101',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '24',
#   'pass_att': '36',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '253',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '7.03',
#   'pass_adj_yds_per_att': '6.33',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2006',
#   'date': '2006-11-19',
#   'week': '11',
#   'age': '29.108',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'GNB',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '31',
#   'pass_cmp_perc': '64.52',
#   'pass_yds': '244',
#   'pass_td': '4',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.87',
#   'pass_adj_yds_per_att': '10.45',
#   'rush_att': '4',
#   'rush_yds': '6',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2006',
#   'date': '2006-11-26',
#   'week': '12',
#   'age': '29.115',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'CHI',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '33',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '267',
#   'pass_td': '1',
#   'pass_int': '2',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '8.09',
#   'pass_adj_yds_per_att': '5.97',
#   'rush_att': '6',
#   'rush_yds': '12',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2006',
#   'date': '2006-12-03',
#   'week': '13',
#   'age': '29.122',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'DET',
#   'started': '*',
#   'pass_comp': '27',
#   'pass_att': '38',
#   'pass_cmp_perc': '71.05',
#   'pass_yds': '305',
#   'pass_td': '0',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '8.03',
#   'pass_adj_yds_per_att': '6.84',
#   'rush_att': '6',
#   'rush_yds': '9',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2006',
#   'date': '2006-12-10',
#   'week': '14',
#   'age': '29.129',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '12',
#   'pass_att': '25',
#   'pass_cmp_perc': '48.00',
#   'pass_yds': '78',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '3.12',
#   'pass_adj_yds_per_att': '3.12',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2006',
#   'date': '2006-12-17',
#   'week': '15',
#   'age': '29.136',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'HOU',
#   'started': '*',
#   'pass_comp': '16',
#   'pass_att': '23',
#   'pass_cmp_perc': '69.57',
#   'pass_yds': '109',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '4.74',
#   'pass_adj_yds_per_att': '6.48',
#   'rush_att': '2',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2006',
#   'date': '2006-12-24',
#   'week': '16',
#   'age': '29.143',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'JAX',
#   'started': '*',
#   'pass_comp': '28',
#   'pass_att': '39',
#   'pass_cmp_perc': '71.79',
#   'pass_yds': '249',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '6.38',
#   'pass_adj_yds_per_att': '6.90',
#   'rush_att': '10',
#   'rush_yds': '31',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2006',
#   'date': '2006-12-31',
#   'week': '17',
#   'age': '29.150',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'TEN',
#   'started': '*',
#   'pass_comp': '15',
#   'pass_att': '24',
#   'pass_cmp_perc': '62.50',
#   'pass_yds': '225',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '9.38',
#   'pass_adj_yds_per_att': '10.21',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-09-09',
#   'week': '1',
#   'age': '30.037',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '28',
#   'pass_cmp_perc': '78.57',
#   'pass_yds': '297',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '10.61',
#   'pass_adj_yds_per_att': '12.75',
#   'rush_att': '1',
#   'rush_yds': '4',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-09-16',
#   'week': '2',
#   'age': '30.044',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'SDG',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '31',
#   'pass_cmp_perc': '80.65',
#   'pass_yds': '279',
#   'pass_td': '3',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '9.00',
#   'pass_adj_yds_per_att': '9.48',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2007',
#   'date': '2007-09-23',
#   'week': '3',
#   'age': '30.051',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '23',
#   'pass_att': '29',
#   'pass_cmp_perc': '79.31',
#   'pass_yds': '311',
#   'pass_td': '4',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '10.72',
#   'pass_adj_yds_per_att': '13.48',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2007',
#   'date': '2007-10-01',
#   'week': '4',
#   'age': '30.059',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'CIN',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '32',
#   'pass_cmp_perc': '78.13',
#   'pass_yds': '231',
#   'pass_td': '3',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.22',
#   'pass_adj_yds_per_att': '7.69',
#   'rush_att': '2',
#   'rush_yds': '-2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-10-07',
#   'week': '5',
#   'age': '30.065',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'CLE',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '38',
#   'pass_cmp_perc': '57.89',
#   'pass_yds': '265',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '6.97',
#   'pass_adj_yds_per_att': '8.55',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-10-14',
#   'week': '6',
#   'age': '30.072',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'DAL',
#   'started': '*',
#   'pass_comp': '31',
#   'pass_att': '46',
#   'pass_cmp_perc': '67.39',
#   'pass_yds': '388',
#   'pass_td': '5',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '8.43',
#   'pass_adj_yds_per_att': '10.61',
#   'rush_att': '3',
#   'rush_yds': '5',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2007',
#   'date': '2007-10-21',
#   'week': '7',
#   'age': '30.079',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '21',
#   'pass_att': '25',
#   'pass_cmp_perc': '84.00',
#   'pass_yds': '354',
#   'pass_td': '6',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '14.16',
#   'pass_adj_yds_per_att': '18.96',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-10-28',
#   'week': '8',
#   'age': '30.086',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'WAS',
#   'started': '*',
#   'pass_comp': '29',
#   'pass_att': '38',
#   'pass_cmp_perc': '76.32',
#   'pass_yds': '306',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.05',
#   'pass_adj_yds_per_att': '9.63',
#   'rush_att': '4',
#   'rush_yds': '14',
#   'rush_td': '2',
#   'fumbles': '1'},
#  {'year': '2007',
#   'date': '2007-11-04',
#   'week': '9',
#   'age': '30.093',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '21',
#   'pass_att': '32',
#   'pass_cmp_perc': '65.63',
#   'pass_yds': '255',
#   'pass_td': '3',
#   'pass_int': '2',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.97',
#   'pass_adj_yds_per_att': '7.03',
#   'rush_att': '5',
#   'rush_yds': '14',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-11-18',
#   'week': '11',
#   'age': '30.107',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '31',
#   'pass_att': '39',
#   'pass_cmp_perc': '79.49',
#   'pass_yds': '373',
#   'pass_td': '5',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '9.56',
#   'pass_adj_yds_per_att': '12.13',
#   'rush_att': '2',
#   'rush_yds': '9',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-11-25',
#   'week': '12',
#   'age': '30.114',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'PHI',
#   'started': '*',
#   'pass_comp': '34',
#   'pass_att': '54',
#   'pass_cmp_perc': '62.96',
#   'pass_yds': '380',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.04',
#   'pass_adj_yds_per_att': '7.41',
#   'rush_att': '3',
#   'rush_yds': '16',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-12-03',
#   'week': '13',
#   'age': '30.122',
#   'team': 'NWE',
#   'away_location': True,
#   'opp': 'BAL',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '38',
#   'pass_cmp_perc': '47.37',
#   'pass_yds': '257',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '6.76',
#   'pass_adj_yds_per_att': '6.63',
#   'rush_att': '2',
#   'rush_yds': '14',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2007',
#   'date': '2007-12-09',
#   'week': '14',
#   'age': '30.128',
#   'team': 'NWE',
#   'away_location': False,
#   'opp': 'PIT',
#   'started': '*',
#   'pass_comp': '32',
#   'pass_att': '46',
#   'pass_cmp_perc': '69.57',
#   'pass_yds': '399',
#   'pass_td': '4',
#   'pass_int': '0',
#   'pass_sacked': '0',
# ...
#   'rush_att': '2',
#   'rush_yds': '-2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2020',
#   'date': '2020-12-26',
#   'week': '16',
#   'age': '43.145',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'DET',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '27',
#   'pass_cmp_perc': '81.48',
#   'pass_yds': '348',
#   'pass_td': '4',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '12.89',
#   'pass_adj_yds_per_att': '15.85',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2020',
#   'date': '2021-01-03',
#   'week': '17',
#   'age': '43.153',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'ATL',
#   'started': '*',
#   'pass_comp': '26',
#   'pass_att': '41',
#   'pass_cmp_perc': '63.41',
#   'pass_yds': '399',
#   'pass_td': '4',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '9.73',
#   'pass_adj_yds_per_att': '10.59',
#   'rush_att': '5',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-09-09',
#   'week': '1',
#   'age': '44.037',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'DAL',
#   'started': '*',
#   'pass_comp': '32',
#   'pass_att': '50',
#   'pass_cmp_perc': '64.00',
#   'pass_yds': '379',
#   'pass_td': '4',
#   'pass_int': '2',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.58',
#   'pass_adj_yds_per_att': '7.38',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-09-19',
#   'week': '2',
#   'age': '44.047',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'ATL',
#   'started': '*',
#   'pass_comp': '24',
#   'pass_att': '36',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '276',
#   'pass_td': '5',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.67',
#   'pass_adj_yds_per_att': '10.44',
#   'rush_att': '1',
#   'rush_yds': '6',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2021',
#   'date': '2021-09-26',
#   'week': '3',
#   'age': '44.054',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'LAR',
#   'started': '*',
#   'pass_comp': '41',
#   'pass_att': '55',
#   'pass_cmp_perc': '74.55',
#   'pass_yds': '432',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.85',
#   'pass_adj_yds_per_att': '8.22',
#   'rush_att': '3',
#   'rush_yds': '14',
#   'rush_td': '1',
#   'fumbles': '1'},
#  {'year': '2021',
#   'date': '2021-10-03',
#   'week': '4',
#   'age': '44.061',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'NWE',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '43',
#   'pass_cmp_perc': '51.16',
#   'pass_yds': '269',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '6.26',
#   'pass_adj_yds_per_att': '6.26',
#   'rush_att': '4',
#   'rush_yds': '3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-10-10',
#   'week': '5',
#   'age': '44.068',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'MIA',
#   'started': '*',
#   'pass_comp': '30',
#   'pass_att': '41',
#   'pass_cmp_perc': '73.17',
#   'pass_yds': '411',
#   'pass_td': '5',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '10.02',
#   'pass_adj_yds_per_att': '12.46',
#   'rush_att': '1',
#   'rush_yds': '13',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-10-14',
#   'week': '6',
#   'age': '44.072',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'PHI',
#   'started': '*',
#   'pass_comp': '34',
#   'pass_att': '42',
#   'pass_cmp_perc': '80.95',
#   'pass_yds': '297',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.07',
#   'pass_adj_yds_per_att': '6.95',
#   'rush_att': '4',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-10-24',
#   'week': '7',
#   'age': '44.082',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'CHI',
#   'started': '*',
#   'pass_comp': '20',
#   'pass_att': '36',
#   'pass_cmp_perc': '55.56',
#   'pass_yds': '211',
#   'pass_td': '4',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '5.86',
#   'pass_adj_yds_per_att': '8.08',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-10-31',
#   'week': '8',
#   'age': '44.089',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'NOR',
#   'started': '*',
#   'pass_comp': '28',
#   'pass_att': '40',
#   'pass_cmp_perc': '70.00',
#   'pass_yds': '375',
#   'pass_td': '4',
#   'pass_int': '2',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '9.38',
#   'pass_adj_yds_per_att': '9.13',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2021',
#   'date': '2021-11-14',
#   'week': '10',
#   'age': '44.103',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'WAS',
#   'started': '*',
#   'pass_comp': '23',
#   'pass_att': '34',
#   'pass_cmp_perc': '67.65',
#   'pass_yds': '220',
#   'pass_td': '2',
#   'pass_int': '2',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '6.47',
#   'pass_adj_yds_per_att': '5.00',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-11-22',
#   'week': '11',
#   'age': '44.111',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'NYG',
#   'started': '*',
#   'pass_comp': '30',
#   'pass_att': '46',
#   'pass_cmp_perc': '65.22',
#   'pass_yds': '307',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '6.67',
#   'pass_adj_yds_per_att': '6.57',
#   'rush_att': '1',
#   'rush_yds': '10',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-11-28',
#   'week': '12',
#   'age': '44.117',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'IND',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '34',
#   'pass_cmp_perc': '73.53',
#   'pass_yds': '226',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.65',
#   'pass_adj_yds_per_att': '5.91',
#   'rush_att': '2',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-12-05',
#   'week': '13',
#   'age': '44.124',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'ATL',
#   'started': '*',
#   'pass_comp': '38',
#   'pass_att': '51',
#   'pass_cmp_perc': '74.51',
#   'pass_yds': '368',
#   'pass_td': '4',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.22',
#   'pass_adj_yds_per_att': '7.90',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-12-12',
#   'week': '14',
#   'age': '44.131',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'BUF',
#   'started': '*',
#   'pass_comp': '31',
#   'pass_att': '46',
#   'pass_cmp_perc': '67.39',
#   'pass_yds': '363',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.89',
#   'pass_adj_yds_per_att': '8.76',
#   'rush_att': '7',
#   'rush_yds': '16',
#   'rush_td': '1',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2021-12-19',
#   'week': '15',
#   'age': '44.138',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'NOR',
#   'started': '*',
#   'pass_comp': '26',
#   'pass_att': '48',
#   'pass_cmp_perc': '54.17',
#   'pass_yds': '214',
#   'pass_td': '0',
#   'pass_int': '1',
#   'pass_sacked': '4',
#   'pass_yds_per_att': '4.46',
#   'pass_adj_yds_per_att': '3.52',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2021',
#   'date': '2021-12-26',
#   'week': '16',
#   'age': '44.145',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'CAR',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '30',
#   'pass_cmp_perc': '60.00',
#   'pass_yds': '232',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '7.73',
#   'pass_adj_yds_per_att': '8.40',
#   'rush_att': '1',
#   'rush_yds': '11',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2022-01-02',
#   'week': '17',
#   'age': '44.152',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'NYJ',
#   'started': '*',
#   'pass_comp': '34',
#   'pass_att': '50',
#   'pass_cmp_perc': '68.00',
#   'pass_yds': '410',
#   'pass_td': '3',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.20',
#   'pass_adj_yds_per_att': '8.50',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2021',
#   'date': '2022-01-09',
#   'week': '18',
#   'age': '44.159',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'CAR',
#   'started': '*',
#   'pass_comp': '29',
#   'pass_att': '37',
#   'pass_cmp_perc': '78.38',
#   'pass_yds': '326',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '8.81',
#   'pass_adj_yds_per_att': '10.43',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-09-11',
#   'week': '1',
#   'age': '45.039',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'DAL',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '27',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '212',
#   'pass_td': '1',
#   'pass_int': '1',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '7.85',
#   'pass_adj_yds_per_att': '6.93',
#   'rush_att': '2',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-09-18',
#   'week': '2',
#   'age': '45.046',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'NOR',
#   'started': '*',
#   'pass_comp': '18',
#   'pass_att': '34',
#   'pass_cmp_perc': '52.94',
#   'pass_yds': '190',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '5.59',
#   'pass_adj_yds_per_att': '6.18',
#   'rush_att': '3',
#   'rush_yds': '-2',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2022',
#   'date': '2022-09-25',
#   'week': '3',
#   'age': '45.053',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'GNB',
#   'started': '*',
#   'pass_comp': '31',
#   'pass_att': '42',
#   'pass_cmp_perc': '73.81',
#   'pass_yds': '271',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '6.45',
#   'pass_adj_yds_per_att': '6.93',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-10-02',
#   'week': '4',
#   'age': '45.060',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'KAN',
#   'started': '*',
#   'pass_comp': '39',
#   'pass_att': '52',
#   'pass_cmp_perc': '75.00',
#   'pass_yds': '385',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.40',
#   'pass_adj_yds_per_att': '8.56',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2022',
#   'date': '2022-10-09',
#   'week': '5',
#   'age': '45.067',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'ATL',
#   'started': '*',
#   'pass_comp': '35',
#   'pass_att': '52',
#   'pass_cmp_perc': '67.31',
#   'pass_yds': '351',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '6.75',
#   'pass_adj_yds_per_att': '7.13',
#   'rush_att': '3',
#   'rush_yds': '-3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-10-16',
#   'week': '6',
#   'age': '45.074',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'PIT',
#   'started': '*',
#   'pass_comp': '25',
#   'pass_att': '40',
#   'pass_cmp_perc': '62.50',
#   'pass_yds': '243',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '2',
#   'pass_yds_per_att': '6.08',
#   'pass_adj_yds_per_att': '6.58',
#   'rush_att': '1',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '1'},
#  {'year': '2022',
#   'date': '2022-10-23',
#   'week': '7',
#   'age': '45.081',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'CAR',
#   'started': '*',
#   'pass_comp': '32',
#   'pass_att': '49',
#   'pass_cmp_perc': '65.31',
#   'pass_yds': '290',
#   'pass_td': '0',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '5.92',
#   'pass_adj_yds_per_att': '5.92',
#   'rush_att': '1',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-10-27',
#   'week': '8',
#   'age': '45.085',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'BAL',
#   'started': '*',
#   'pass_comp': '26',
#   'pass_att': '44',
#   'pass_cmp_perc': '59.09',
#   'pass_yds': '325',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '7.39',
#   'pass_adj_yds_per_att': '7.84',
#   'rush_att': '1',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-11-06',
#   'week': '9',
#   'age': '45.095',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'LAR',
#   'started': '*',
#   'pass_comp': '36',
#   'pass_att': '58',
#   'pass_cmp_perc': '62.07',
#   'pass_yds': '280',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '4.83',
#   'pass_adj_yds_per_att': '5.17',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-11-13',
#   'week': '10',
#   'age': '45.102',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'SEA',
#   'started': '*',
#   'pass_comp': '22',
#   'pass_att': '29',
#   'pass_cmp_perc': '75.86',
#   'pass_yds': '258',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '8.90',
#   'pass_adj_yds_per_att': '8.72',
#   'rush_att': '6',
#   'rush_yds': '-3',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-11-27',
#   'week': '12',
#   'age': '45.116',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'CLE',
#   'started': '*',
#   'pass_comp': '29',
#   'pass_att': '43',
#   'pass_cmp_perc': '67.44',
#   'pass_yds': '246',
#   'pass_td': '2',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '5.72',
#   'pass_adj_yds_per_att': '6.65',
#   'rush_att': '1',
#   'rush_yds': '2',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-12-05',
#   'week': '13',
#   'age': '45.124',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'NOR',
#   'started': '*',
#   'pass_comp': '36',
#   'pass_att': '54',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '281',
#   'pass_td': '2',
#   'pass_int': '1',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '5.20',
#   'pass_adj_yds_per_att': '5.11',
#   'rush_att': '1',
#   'rush_yds': '-1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-12-11',
#   'week': '14',
#   'age': '45.130',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'SFO',
#   'started': '*',
#   'pass_comp': '34',
#   'pass_att': '55',
#   'pass_cmp_perc': '61.82',
#   'pass_yds': '253',
#   'pass_td': '1',
#   'pass_int': '2',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '4.60',
#   'pass_adj_yds_per_att': '3.33',
#   'rush_att': '2',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2022-12-18',
#   'week': '15',
#   'age': '45.137',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'CIN',
#   'started': '*',
#   'pass_comp': '30',
#   'pass_att': '44',
#   'pass_cmp_perc': '68.18',
#   'pass_yds': '312',
#   'pass_td': '3',
#   'pass_int': '2',
#   'pass_sacked': '1',
#   'pass_yds_per_att': '7.09',
#   'pass_adj_yds_per_att': '6.41',
#   'rush_att': '2',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '2'},
#  {'year': '2022',
#   'date': '2022-12-25',
#   'week': '16',
#   'age': '45.144',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'ARI',
#   'started': '*',
#   'pass_comp': '32',
#   'pass_att': '48',
#   'pass_cmp_perc': '66.67',
#   'pass_yds': '281',
#   'pass_td': '1',
#   'pass_int': '2',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '5.85',
#   'pass_adj_yds_per_att': '4.40',
#   'rush_att': '2',
#   'rush_yds': '1',
#   'rush_td': '0',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2023-01-01',
#   'week': '17',
#   'age': '45.151',
#   'team': 'TAM',
#   'away_location': False,
#   'opp': 'CAR',
#   'started': '*',
#   'pass_comp': '34',
#   'pass_att': '45',
#   'pass_cmp_perc': '75.56',
#   'pass_yds': '432',
#   'pass_td': '3',
#   'pass_int': '0',
#   'pass_sacked': '3',
#   'pass_yds_per_att': '9.60',
#   'pass_adj_yds_per_att': '10.93',
#   'rush_att': '3',
#   'rush_yds': '4',
#   'rush_td': '1',
#   'fumbles': '0'},
#  {'year': '2022',
#   'date': '2023-01-08',
#   'week': '18',
#   'age': '45.158',
#   'team': 'TAM',
#   'away_location': True,
#   'opp': 'ATL',
#   'started': '*',
#   'pass_comp': '13',
#   'pass_att': '17',
#   'pass_cmp_perc': '76.47',
#   'pass_yds': '84',
#   'pass_td': '1',
#   'pass_int': '0',
#   'pass_sacked': '0',
#   'pass_yds_per_att': '4.94',
#   'pass_adj_yds_per_att': '6.12',
#   'rush_att': '0',
#   'rush_yds': '0',
#   'rush_td': '0',
#   'fumbles': '0'}]

# %%
load_dotenv()
DB_USERNAME = os.environ['DB_USERNAME']
DB_PASSWORD = os.environ['DB_PASSWORD']
DB_HOST = os.environ['DB_HOST']
DB_PORT = os.environ['DB_PORT']
DB_NAME = os.environ['DB_NAME']

# Construct the database URL
DB_URL = f"postgresql://{DB_USERNAME}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(DB_URL)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
player_data
# Out:
# {'name': 'QB',
#  'height_cm': 193,
#  'weight_kg': 102,
#  'dob': '1977-08-03',
#  'college': 'Michigan',
#  'drafted_overall': 199,
#  'drafted_year': 2000}

# %%
test_player = Player(**player_data)
# Out:
# ---------------------------------------------------------------------------
# AmbiguousForeignKeysError                 Traceback (most recent call last)
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\relationships.py:2418, in JoinCondition._determine_joins(self)
#    2417 if self.primaryjoin_initial is None:
# -> 2418     self.primaryjoin = join_condition(
#    2419         self.parent_persist_selectable,
#    2420         self.child_persist_selectable,
#    2421         a_subset=self.parent_local_selectable,
#    2422         consider_as_foreign_keys=consider_as_foreign_keys,
#    2423     )
#    2424 else:
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\sql\util.py:123, in join_condition(a, b, a_subset, consider_as_foreign_keys)
#     101 """Create a join condition between two tables or selectables.
#     102
#     103 e.g.::
#    (...)
#     121
#     122 """
# --> 123 return Join._join_condition(
#     124     a,
#     125     b,
#     126     a_subset=a_subset,
#     127     consider_as_foreign_keys=consider_as_foreign_keys,
#     128 )
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\sql\selectable.py:1348, in Join._join_condition(cls, a, b, a_subset, consider_as_foreign_keys)
#    1347 if len(constraints) > 1:
# -> 1348     cls._joincond_trim_constraints(
#    1349         a, b, constraints, consider_as_foreign_keys
#    1350     )
#    1352 if len(constraints) == 0:
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\sql\selectable.py:1493, in Join._joincond_trim_constraints(cls, a, b, constraints, consider_as_foreign_keys)
#    1492 if len(constraints) != 1:
# -> 1493     raise exc.AmbiguousForeignKeysError(
#    1494         "Can't determine join between '%s' and '%s'; "
#    1495         "tables have more than one foreign key "
#    1496         "constraint relationship between them. "
#    1497         "Please specify the 'onclause' of this "
#    1498         "join explicitly." % (a.description, b.description)
#    1499     )
#
# AmbiguousForeignKeysError: Can't determine join between 'team_game_stats' and 'game'; tables have more than one foreign key constraint relationship between them. Please specify the 'onclause' of this join explicitly.
#
# The above exception was the direct cause of the following exception:
#
# AmbiguousForeignKeysError                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 test_player = Player(**player_data)
#
# File <string>:4, in __init__(self, **kwargs)
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\state.py:561, in InstanceState._initialize_instance(*mixed, **kwargs)
#     558 self, instance, args = mixed[0], mixed[1], mixed[2:]  # noqa
#     559 manager = self.manager
# --> 561 manager.dispatch.init(self, args, kwargs)
#     563 try:
#     564     manager.original_init(*mixed[1:], **kwargs)
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\event\attr.py:487, in _CompoundListener.__call__(self, *args, **kw)
#     485     fn(*args, **kw)
#     486 for fn in self.listeners:
# --> 487     fn(*args, **kw)
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\mapper.py:4391, in _event_on_init(state, args, kwargs)
#    4389 instrumenting_mapper = state.manager.mapper
#    4390 if instrumenting_mapper:
# -> 4391     instrumenting_mapper._check_configure()
#    4392     if instrumenting_mapper._set_polymorphic_identity:
#    4393         instrumenting_mapper._set_polymorphic_identity(state)
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\mapper.py:2386, in Mapper._check_configure(self)
#    2378 @util.langhelpers.tag_method_for_warnings(
#    2379     "This warning originated from the `configure_mappers()` process, "
#    2380     "which was invoked automatically in response to a user-initiated "
#    (...)
#    2383 )
#    2384 def _check_configure(self) -> None:
#    2385     if self.registry._new_mappers:
# -> 2386         _configure_registries({self.registry}, cascade=True)
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\mapper.py:4199, in _configure_registries(registries, cascade)
#    4193     Mapper.dispatch._for_class(Mapper).before_configured()  # type: ignore # noqa: E501
#    4194     # initialize properties on all mappers
#    4195     # note that _mapper_registry is unordered, which
#    4196     # may randomly conceal/reveal issues related to
#    4197     # the order of mapper compilation
# -> 4199     _do_configure_registries(registries, cascade)
#    4200 finally:
#    4201     _already_compiling = False
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\mapper.py:4240, in _do_configure_registries(registries, cascade)
#    4238 if not mapper.configured:
#    4239     try:
# -> 4240         mapper._post_configure_properties()
#    4241         mapper._expire_memoizations()
#    4242         mapper.dispatch.mapper_configured(mapper, mapper.class_)
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\mapper.py:2403, in Mapper._post_configure_properties(self)
#    2400 self._log("initialize prop %s", key)
#    2402 if prop.parent is self and not prop._configure_started:
# -> 2403     prop.init()
#    2405 if prop._configure_finished:
#    2406     prop.post_instrument_class(self)
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\interfaces.py:578, in MapperProperty.init(self)
#     571 """Called after all mappers are created to assemble
#     572 relationships between mappers and perform other post-mapper-creation
#     573 initialization steps.
#     574
#     575
#     576 """
#     577 self._configure_started = True
# --> 578 self.do_init()
#     579 self._configure_finished = True
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\relationships.py:1636, in RelationshipProperty.do_init(self)
#    1634 self._setup_entity()
#    1635 self._setup_registry_dependencies()
# -> 1636 self._setup_join_conditions()
#    1637 self._check_cascade_settings(self._cascade)
#    1638 self._post_init()
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\relationships.py:1881, in RelationshipProperty._setup_join_conditions(self)
#    1880 def _setup_join_conditions(self) -> None:
# -> 1881     self._join_condition = jc = JoinCondition(
#    1882         parent_persist_selectable=self.parent.persist_selectable,
#    1883         child_persist_selectable=self.entity.persist_selectable,
#    1884         parent_local_selectable=self.parent.local_table,
#    1885         child_local_selectable=self.entity.local_table,
#    1886         primaryjoin=self._init_args.primaryjoin.resolved,
#    1887         secondary=self._init_args.secondary.resolved,
#    1888         secondaryjoin=self._init_args.secondaryjoin.resolved,
#    1889         parent_equivalents=self.parent._equivalent_columns,
#    1890         child_equivalents=self.mapper._equivalent_columns,
#    1891         consider_as_foreign_keys=self._user_defined_foreign_keys,
#    1892         local_remote_pairs=self.local_remote_pairs,
#    1893         remote_side=self.remote_side,
#    1894         self_referential=self._is_self_referential,
#    1895         prop=self,
#    1896         support_sync=not self.viewonly,
#    1897         can_be_synced_fn=self._columns_are_mapped,
#    1898     )
#    1899     self.primaryjoin = jc.primaryjoin
#    1900     self.secondaryjoin = jc.secondaryjoin
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\relationships.py:2305, in JoinCondition.__init__(self, parent_persist_selectable, child_persist_selectable, parent_local_selectable, child_local_selectable, primaryjoin, secondary, secondaryjoin, parent_equivalents, child_equivalents, consider_as_foreign_keys, local_remote_pairs, remote_side, self_referential, prop, support_sync, can_be_synced_fn)
#    2302 self.support_sync = support_sync
#    2303 self.can_be_synced_fn = can_be_synced_fn
# -> 2305 self._determine_joins()
#    2306 assert self.primaryjoin is not None
#    2308 self._sanitize_joins()
#
# File ~\Coding Project\Fantasy Analysis\venv\lib\site-packages\sqlalchemy\orm\relationships.py:2462, in JoinCondition._determine_joins(self)
#    2450     raise sa_exc.AmbiguousForeignKeysError(
#    2451         "Could not determine join "
#    2452         "condition between parent/child tables on "
#    (...)
#    2459         "parent and child tables." % (self.prop, self.secondary)
#    2460     ) from afe
#    2461 else:
# -> 2462     raise sa_exc.AmbiguousForeignKeysError(
#    2463         "Could not determine join "
#    2464         "condition between parent/child tables on "
#    2465         "relationship %s - there are multiple foreign key "
#    2466         "paths linking the tables.  Specify the "
#    2467         "'foreign_keys' argument, providing a list of those "
#    2468         "columns which should be counted as containing a "
#    2469         "foreign key reference to the parent table." % self.prop
#    2470     ) from afe
#
# AmbiguousForeignKeysError: Could not determine join condition between parent/child tables on relationship TeamGameStats.game - there are multiple foreign key paths linking the tables.  Specify the 'foreign_keys' argument, providing a list of those columns which should be counted as containing a foreign key reference to the parent table.
