# %%
import polars as pl
from google.cloud import storage
import pyarrow

# %%
BUCKET_NAME = "nfl-data-bronze"
LOAD_DATE = "2025-09-28"

DATASETS = {
    'fantasy_ids': f'bronze/fantasy_ids/load_date={LOAD_DATE}/ff_playerids.parquet',
    'play_by_play': f'bronze/play_by_play/load_date={LOAD_DATE}/pbp_all_seasons.parquet',
    'player_stats': f'bronze/player_stats/load_date={LOAD_DATE}/player_stats_all_seasons.parquet',
    'players': f'bronze/players/load_date={LOAD_DATE}/players.parquet',
    'rosters': f'bronze/rosters/load_date={LOAD_DATE}/rosters_all_seasons.parquet',
    'schedules': f'bronze/schedules/load_date={LOAD_DATE}/schedules_all_seasons.parquet',
    'team_stats': f'bronze/team_stats/load_date={LOAD_DATE}/team_stats.parquet'
}

# %%
def list_available_files(bucket_name: str, prefix: str = ""):
    """List all available files in the GCS bucket to help identify correct paths"""
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    
    print(f"📁 Files in gs://{bucket_name}/{prefix}:")
    print("-" * 60)
    
    blobs = bucket.list_blobs(prefix=prefix)
    files = []
    
    for blob in blobs:
        if blob.name.endswith('.parquet'):
            size_mb = blob.size / (1024 * 1024)
            print(f"  📄 {blob.name} ({size_mb:.1f} MB)")
            files.append(blob.name)
    
    return files

# %%
def load_dataset_sample(bucket_name: str, file_path: str, sample_size: int = 10) -> dict:
    """Load a sample of data from GCS and return info about the dataset"""
    try:
        gcs_path = f"gs://{bucket_name}/{file_path}"
        print(f"\n🔍 Loading sample from: {file_path}")
        
        # Read just a sample for inspection
        df = pl.read_parquet(gcs_path)
        
        # Get dataset info
        info = {
            'path': file_path,
            'total_rows': df.height,
            'total_columns': df.width,
            'columns': df.columns,
            'dtypes': dict(df.schema),
            'sample_data': df.head(sample_size),
            'memory_usage_mb': df.estimated_size('mb')
        }
        
        print(f"  ✅ Total rows: {info['total_rows']:,}")
        print(f"  ✅ Total columns: {info['total_columns']}")
        print(f"  ✅ Estimated size: {info['memory_usage_mb']:.1f} MB")
        
        return info
        
    except Exception as e:
        print(f"  ❌ Error loading {file_path}: {e}")
        return None

# %%
def inspect_all_datasets(bucket_name: str, datasets: dict, sample_size: int = 10):
    """Load and inspect all datasets - Pure Polars version"""
    
    print("=" * 70)
    print("🏈 NFL DATA INSPECTOR")
    print("=" * 70)
    
    # First, let's see what files are actually available
    print("\n📋 AVAILABLE FILES:")
    available_files = list_available_files(bucket_name)
    
    if not available_files:
        print("❌ No parquet files found. Check your bucket name and ensure data has been loaded.")
        return {}
    
    print(f"\n🔎 INSPECTING DATASETS (showing top {sample_size} rows each):")
    print("=" * 70)
    
    dataset_info = {}
    
    for dataset_name, expected_path in datasets.items():
        print(f"\n📊 DATASET: {dataset_name.upper()}")
        print("-" * 50)
        
        # Try the expected path first
        info = load_dataset_sample(bucket_name, expected_path, sample_size)
        
        if info is None:
            # If expected path fails, try to find alternative paths
            print(f"  🔍 Searching for alternative paths...")
            possible_paths = [f for f in available_files if dataset_name in f.lower() or any(keyword in f.lower() for keyword in dataset_name.split('_'))]
            
            if possible_paths:
                print(f"  📂 Found possible alternatives:")
                for path in possible_paths[:3]:  # Show up to 3 alternatives
                    print(f"    - {path}")
                
                # Try the first alternative
                info = load_dataset_sample(bucket_name, possible_paths[0], sample_size)
        
        if info:
            dataset_info[dataset_name] = info
            
            # Display column info
            print(f"\n  📋 COLUMNS ({len(info['columns'])}):")
            for col, dtype in list(info['dtypes'].items())[:10]:  # Show first 10 columns
                print(f"    • {col}: {dtype}")
            if len(info['dtypes']) > 10:
                print(f"    ... and {len(info['dtypes']) - 10} more columns")
            
            # Display sample data using pure Polars (NO PANDAS)
            print(f"\n  📊 SAMPLE DATA (top {sample_size} rows):")
            
            sample_df = info['sample_data']  # This is already a Polars DataFrame
            
            # Limit columns for display if too many
            if len(sample_df.columns) > 8:
                display_cols = sample_df.columns[:8]
                sample_display = sample_df.select(display_cols)
                print(f"    (Showing first 8 of {len(sample_df.columns)} columns)")
            else:
                sample_display = sample_df
            
            # Use Polars' built-in display (NO .to_pandas() call)
            print(sample_display)
        
        print("\n" + "=" * 50)
    
    return dataset_info

# %%
all_dataset_info = inspect_all_datasets(BUCKET_NAME, DATASETS, sample_size=10)
    
# Summary
print(f"\n📈 SUMMARY:")
print("=" * 50)

total_rows = sum(info['total_rows'] for info in all_dataset_info.values())
total_size_mb = sum(info['memory_usage_mb'] for info in all_dataset_info.values())

print(f"✅ Successfully loaded {len(all_dataset_info)} datasets")
print(f"📊 Total records across all datasets: {total_rows:,}")
print(f"💾 Total estimated size: {total_size_mb:.1f} MB")

print(f"\n📋 Dataset breakdown:")
for name, info in all_dataset_info.items():
    print(f"  • {name}: {info['total_rows']:,} rows, {info['total_columns']} cols, {info['memory_usage_mb']:.1f} MB")

print(f"\n🎯 Ready for silver layer processing!")

# Extended Overview - Columns and Head(3) for each dataset
print(f"\n" + "=" * 80)
print(f"📊 DETAILED DATASET OVERVIEW")
print(f"=" * 80)

for dataset_name, info in all_dataset_info.items():
    print(f"\n🏈 {dataset_name.upper()}")
    print("-" * 60)
    
    print(f"📏 Shape: {info['total_rows']:,} rows × {info['total_columns']} columns")
    print(f"📁 Path: {info['path']}")
    
    print(f"\n📋 COLUMNS ({info['total_columns']}):")
    for i, (col, dtype) in enumerate(info['dtypes'].items(), 1):
        print(f"  {i:2d}. {col:30} | {dtype}")
    
    print(f"\n📊 SAMPLE DATA (first 3 rows):")
    sample_data = info['sample_data'].head(3)  # Get just 3 rows
    
    # If too many columns, show first 8
    if len(sample_data.columns) > 8:
        display_cols = sample_data.columns
        display_df = sample_data.select(display_cols)
        print(f"    (Showing {len(sample_data.columns)} columns)")
        print(display_df)
    else:
        print(sample_data)
    
    print("\n" + "=" * 80)

print(f"\n🚀 Overview complete! All datasets ready for analysis.")
# Out:
# ======================================================================
# 🏈 NFL DATA INSPECTOR
# ======================================================================
#
# 📋 AVAILABLE FILES:
# 📁 Files in gs://nfl-data-bronze/:
# ------------------------------------------------------------
#   📄 bronze/fantasy_ids/load_date=2025-09-28/ff_playerids.parquet (0.9 MB)
#   📄 bronze/play_by_play/load_date=2025-09-28/pbp_2023.parquet (12.8 MB)
#   📄 bronze/play_by_play/load_date=2025-09-28/pbp_2024.parquet (12.8 MB)
#   📄 bronze/play_by_play/load_date=2025-09-28/pbp_2025.parquet (2.4 MB)
#   📄 bronze/play_by_play/load_date=2025-09-28/pbp_all_seasons.parquet (291.1 MB)
#   📄 bronze/player_stats/load_date=2025-09-28/player_stats_all_seasons.parquet (10.2 MB)
#   📄 bronze/players/load_date=2025-09-27/players.parquet (3.2 MB)
#   📄 bronze/players/load_date=2025-09-28/players.parquet (2.0 MB)
#   📄 bronze/rosters/load_date=2025-09-28/rosters_all_seasons.parquet (2.8 MB)
#   📄 bronze/schedules/load_date=2025-09-28/schedules_all_seasons.parquet (0.3 MB)
#   📄 bronze/team_stats/load_date=2025-09-28/team_stats.parquet (0.9 MB)
#
# 🔎 INSPECTING DATASETS (showing top 10 rows each):
# ======================================================================
#
# 📊 DATASET: FANTASY_IDS
# --------------------------------------------------
#
# 🔍 Loading sample from: bronze/fantasy_ids/load_date=2025-09-28/ff_playerids.parquet
#   ✅ Total rows: 12,133
#   ✅ Total columns: 35
#   ✅ Estimated size: 3.4 MB
#
#   📋 COLUMNS (35):
#     • mfl_id: Int64
#     • sportradar_id: String
#     • fantasypros_id: Int64
#     • gsis_id: String
#     • pff_id: Int64
#     • sleeper_id: Int64
#     • nfl_id: Int64
#     • espn_id: Int64
#     • yahoo_id: String
#     • fleaflicker_id: String
#     ... and 25 more columns
#
#   📊 SAMPLE DATA (top 10 rows):
#     (Showing first 8 of 35 columns)
# shape: (10, 8)
# ┌────────┬──────────────────┬────────────────┬────────────┬────────┬────────────┬────────┬─────────┐
# │ mfl_id ┆ sportradar_id    ┆ fantasypros_id ┆ gsis_id    ┆ pff_id ┆ sleeper_id ┆ nfl_id ┆ espn_id │
# │ ---    ┆ ---              ┆ ---            ┆ ---        ┆ ---    ┆ ---        ┆ ---    ┆ ---     │
# │ i64    ┆ str              ┆ i64            ┆ str        ┆ i64    ┆ i64        ┆ i64    ┆ i64     │
# ╞════════╪══════════════════╪════════════════╪════════════╪════════╪════════════╪════════╪═════════╡
# │ 17030  ┆ 3c76cab3-3df2-43 ┆ 24755          ┆ 00-0040676 ┆ 133244 ┆ 12522      ┆ 58203  ┆ 4688380 │
# │        ┆ dd-acaa-57e055…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17031  ┆ 270e09bc-8bf8-44 ┆ 25968          ┆ 00-0040668 ┆ 131396 ┆ 12524      ┆ 58349  ┆ 4432762 │
# │        ┆ b0-87ed-1fd014…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17032  ┆ 53848cba-bcad-4c ┆ 23160          ┆ 00-0040691 ┆ 146409 ┆ 12508      ┆ 58227  ┆ 4689114 │
# │        ┆ d0-bb35-0a1f6e…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17033  ┆ b0eb5b67-4ef2-46 ┆ 22884          ┆ 00-0040673 ┆ 146590 ┆ 12510      ┆ 58297  ┆ 4432734 │
# │        ┆ 2d-bfe7-e73bcc…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17034  ┆ d89f0384-21a6-44 ┆ 23680          ┆ 00-0040234 ┆ 127253 ┆ 12500      ┆ 58436  ┆ 4889929 │
# │        ┆ e4-8aa6-324cb2…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17035  ┆ 38b62d7f-4403-4e ┆ 25373          ┆ 00-0040206 ┆ 143862 ┆ 12470      ┆ 58394  ┆ 4683423 │
# │        ┆ 2b-8083-4d0cd0…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17036  ┆ b8a1b579-3a7e-48 ┆ 25972          ┆ 00-0040203 ┆ 122599 ┆ 12511      ┆ 58390  ┆ 4429955 │
# │        ┆ 58-960b-fbfaca…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17037  ┆ 299d4fe8-188c-43 ┆ 23150          ┆ 00-0040704 ┆ 86272  ┆ 12486      ┆ 58299  ┆ 4427238 │
# │        ┆ d1-95d3-8a8f10…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17038  ┆ 451c7689-4fc2-41 ┆ 23066          ┆ 00-0040014 ┆ 145053 ┆ 12494      ┆ 58386  ┆ 4433971 │
# │        ┆ 0a-a33f-22dfa2…  ┆                ┆            ┆        ┆            ┆        ┆         │
# │ 17039  ┆ 94b8f9e1-3109-44 ┆ 23096          ┆ 00-0040743 ┆ 83537  ┆ 12545      ┆ 58245  ┆ 4360689 │
# │        ┆ 29-8f71-4f79d7…  ┆                ┆            ┆        ┆            ┆        ┆         │
# └────────┴──────────────────┴────────────────┴────────────┴────────┴────────────┴────────┴─────────┘
#
# ==================================================
#
# 📊 DATASET: PLAY_BY_PLAY
# --------------------------------------------------
#
# 🔍 Loading sample from: bronze/play_by_play/load_date=2025-09-28/pbp_all_seasons.parquet
#   ✅ Total rows: 1,239,309
#   ✅ Total columns: 372
#   ✅ Estimated size: 3425.5 MB
#
#   📋 COLUMNS (372):
#     • play_id: Float64
#     • game_id: String
#     • old_game_id: String
#     • home_team: String
#     • away_team: String
#     • season_type: String
#     • week: Int32
#     • posteam: String
#     • posteam_type: String
#     • defteam: String
#     ... and 362 more columns
#
#   📊 SAMPLE DATA (top 10 rows):
#     (Showing first 8 of 372 columns)
# shape: (10, 8)
# ┌─────────┬─────────────────┬─────────────┬───────────┬───────────┬─────────────┬──────┬─────────┐
# │ play_id ┆ game_id         ┆ old_game_id ┆ home_team ┆ away_team ┆ season_type ┆ week ┆ posteam │
# │ ---     ┆ ---             ┆ ---         ┆ ---       ┆ ---       ┆ ---         ┆ ---  ┆ ---     │
# │ f64     ┆ str             ┆ str         ┆ str       ┆ str       ┆ str         ┆ i32  ┆ str     │
# ╞═════════╪═════════════════╪═════════════╪═══════════╪═══════════╪═════════════╪══════╪═════════╡
# │ 35.0    ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ PHI     │
# │ 60.0    ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ PHI     │
# │ 82.0    ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ PHI     │
# │ 103.0   ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ PHI     │
# │ 126.0   ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ PHI     │
# │ 150.0   ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ PHI     │
# │ 176.0   ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ ARI     │
# │ 197.0   ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ ARI     │
# │ 218.0   ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ ARI     │
# │ 240.0   ┆ 1999_01_ARI_PHI ┆ 1999091200  ┆ PHI       ┆ ARI       ┆ REG         ┆ 1    ┆ ARI     │
# └─────────┴─────────────────┴─────────────┴───────────┴───────────┴─────────────┴──────┴─────────┘
#
# ==================================================
#
# 📊 DATASET: PLAYER_STATS
# --------------------------------------------------
#
# 🔍 Loading sample from: bronze/player_stats/load_date=2025-09-28/player_stats_all_seasons.parquet
#   ✅ Total rows: 460,089
#   ✅ Total columns: 114
#   ✅ Estimated size: 265.1 MB
#
#   📋 COLUMNS (114):
#     • player_id: String
#     • player_name: String
#     • player_display_name: String
#     • position: String
#     • position_group: String
#     • headshot_url: String
#     • season: Int32
#     • week: Int32
#     • season_type: String
#     • team: String
#     ... and 104 more columns
#
#   📊 SAMPLE DATA (top 10 rows):
#     (Showing first 8 of 114 columns)
# shape: (10, 8)
# ┌────────────┬─────────────┬──────────────┬──────────┬──────────────┬──────────────┬────────┬──────┐
# │ player_id  ┆ player_name ┆ player_displ ┆ position ┆ position_gro ┆ headshot_url ┆ season ┆ week │
# │ ---        ┆ ---         ┆ ay_name      ┆ ---      ┆ up           ┆ ---          ┆ ---    ┆ ---  │
# │ str        ┆ str         ┆ ---          ┆ str      ┆ ---          ┆ str          ┆ i32    ┆ i32  │
# │            ┆             ┆ str          ┆          ┆ str          ┆              ┆        ┆      │
# ╞════════════╪═════════════╪══════════════╪══════════╪══════════════╪══════════════╪════════╪══════╡
# │ 0          ┆ null        ┆ null         ┆ null     ┆ null         ┆ null         ┆ 1999   ┆ 1    │
# │ 00-0000003 ┆ A.al-Jabbar ┆ Abdul-Karim  ┆ RB       ┆ RB           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆ al-Jabbar    ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000007 ┆ R.Abdullah  ┆ Rabih        ┆ RB       ┆ RB           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆ Abdullah     ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000008 ┆ R.Abdullah  ┆ Rahim        ┆ OLB      ┆ LB           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆ Abdullah     ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000017 ┆ D.Abraham   ┆ Donnie       ┆ CB       ┆ DB           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆ Abraham      ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000045 ┆ F.Adams     ┆ Flozell      ┆ OT       ┆ OL           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆ Adams        ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000065 ┆ S.Adams     ┆ Sam Adams    ┆ DT       ┆ DL           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆              ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000100 ┆ C.Ahanotu   ┆ Chidi        ┆ DT       ┆ DL           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆ Ahanotu      ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000104 ┆ T.Aikman    ┆ Troy Aikman  ┆ QB       ┆ QB           ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆              ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# │ 00-0000108 ┆ D.Akers     ┆ David Akers  ┆ K        ┆ SPEC         ┆ https://stat ┆ 1999   ┆ 1    │
# │            ┆             ┆              ┆          ┆              ┆ ic.www.nfl.c ┆        ┆      │
# │            ┆             ┆              ┆          ┆              ┆ om/ima…      ┆        ┆      │
# └────────────┴─────────────┴──────────────┴──────────┴──────────────┴──────────────┴────────┴──────┘
#
# ==================================================
#
# 📊 DATASET: PLAYERS
# --------------------------------------------------
#
# 🔍 Loading sample from: bronze/players/load_date=2025-09-28/players.parquet
#   ✅ Total rows: 24,311
#   ✅ Total columns: 39
#   ✅ Estimated size: 7.5 MB
#
#   📋 COLUMNS (39):
#     • gsis_id: String
#     • display_name: String
#     • common_first_name: String
#     • first_name: String
#     • last_name: String
#     • short_name: String
#     • football_name: String
#     • suffix: String
#     • esb_id: String
#     • nfl_id: String
#     ... and 29 more columns
#
#   📊 SAMPLE DATA (top 10 rows):
#     (Showing first 8 of 39 columns)
# shape: (10, 8)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┬────────┐
# │ gsis_id    ┆ display_na ┆ common_fir ┆ first_name ┆ last_name  ┆ short_name ┆ football_ ┆ suffix │
# │ ---        ┆ me         ┆ st_name    ┆ ---        ┆ ---        ┆ ---        ┆ name      ┆ ---    │
# │ str        ┆ ---        ┆ ---        ┆ str        ┆ str        ┆ str        ┆ ---       ┆ str    │
# │            ┆ str        ┆ str        ┆            ┆            ┆            ┆ str       ┆        │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪════════╡
# │ 00-0028830 ┆ Isaako     ┆ Isaako     ┆ Isaako     ┆ Aaitui     ┆ null       ┆ null      ┆ null   │
# │            ┆ Aaitui     ┆            ┆            ┆            ┆            ┆           ┆        │
# │ 00-0038389 ┆ Israel     ┆ Israel     ┆ Israel     ┆ Abanikanda ┆ I.Abanikan ┆ Israel    ┆ null   │
# │            ┆ Abanikanda ┆            ┆            ┆            ┆ da         ┆           ┆        │
# │ 00-0024644 ┆ Jon Abbate ┆ Jon        ┆ Jon        ┆ Abbate     ┆ null       ┆ null      ┆ null   │
# │ ABB498348  ┆ Vince      ┆ Vince      ┆ Vincent    ┆ Abbott     ┆ null       ┆ null      ┆ null   │
# │            ┆ Abbott     ┆            ┆            ┆            ┆            ┆           ┆        │
# │ 00-0031021 ┆ Jared      ┆ Jared      ┆ Jared      ┆ Abbrederis ┆ J.Abbreder ┆ Jared     ┆ null   │
# │            ┆ Abbrederis ┆            ┆            ┆            ┆ is         ┆           ┆        │
# │ 00-0032860 ┆ Mehdi      ┆ Mehdi      ┆ Mehdi      ┆ Abdesmad   ┆ M.Abdesmad ┆ Mehdi     ┆ null   │
# │            ┆ Abdesmad   ┆            ┆            ┆            ┆            ┆           ┆        │
# │ 00-0028564 ┆ Isa Abdul- ┆ Isa        ┆ Isa        ┆ Abdul-Qudd ┆ null       ┆ Isa       ┆ null   │
# │            ┆ Quddus     ┆            ┆            ┆ us         ┆            ┆           ┆        │
# │ 00-0032104 ┆ Ameer      ┆ Ameer      ┆ Ameer      ┆ Abdullah   ┆ A.Abdullah ┆ Ameer     ┆ null   │
# │            ┆ Abdullah   ┆            ┆            ┆            ┆            ┆           ┆        │
# │ 00-0023663 ┆ Hamza      ┆ Hamza      ┆ Hamza      ┆ Abdullah   ┆ null       ┆ null      ┆ null   │
# │            ┆ Abdullah   ┆            ┆            ┆            ┆            ┆           ┆        │
# │ 00-0025940 ┆ Husain     ┆ Husain     ┆ Husain     ┆ Abdullah   ┆ null       ┆ Husain    ┆ null   │
# │            ┆ Abdullah   ┆            ┆            ┆            ┆            ┆           ┆        │
# └────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┴────────┘
#
# ==================================================
#
# 📊 DATASET: ROSTERS
# --------------------------------------------------
#
# 🔍 Loading sample from: bronze/rosters/load_date=2025-09-28/rosters_all_seasons.parquet
#   ✅ Total rows: 66,412
#   ✅ Total columns: 36
#   ✅ Estimated size: 19.8 MB
#
#   📋 COLUMNS (36):
#     • season: Int32
#     • team: String
#     • position: String
#     • depth_chart_position: String
#     • jersey_number: String
#     • status: String
#     • full_name: String
#     • first_name: String
#     • last_name: String
#     • birth_date: Date
#     ... and 26 more columns
#
#   📊 SAMPLE DATA (top 10 rows):
#     (Showing first 8 of 36 columns)
# shape: (10, 8)
# ┌────────┬──────┬──────────┬────────────────┬───────────────┬────────┬───────────────┬─────────────┐
# │ season ┆ team ┆ position ┆ depth_chart_po ┆ jersey_number ┆ status ┆ full_name     ┆ first_name  │
# │ ---    ┆ ---  ┆ ---      ┆ sition         ┆ ---           ┆ ---    ┆ ---           ┆ ---         │
# │ i32    ┆ str  ┆ str      ┆ ---            ┆ str           ┆ str    ┆ str           ┆ str         │
# │        ┆      ┆          ┆ str            ┆               ┆        ┆               ┆             │
# ╞════════╪══════╪══════════╪════════════════╪═══════════════╪════════╪═══════════════╪═════════════╡
# │ 1999   ┆ CLE  ┆ RB       ┆ RB             ┆ 27            ┆ ACT    ┆ Abdul-Karim   ┆ Abdul-Karim │
# │        ┆      ┆          ┆                ┆               ┆        ┆ al-Jabbar     ┆             │
# │ 1999   ┆ MIA  ┆ RB       ┆ RB             ┆ 33            ┆ TRD    ┆ Abdul-Karim   ┆ Abdul-Karim │
# │        ┆      ┆          ┆                ┆               ┆        ┆ al-Jabbar     ┆             │
# │ 1999   ┆ TB   ┆ RB       ┆ RB             ┆ 27            ┆ RES    ┆ Rabih         ┆ Rabih       │
# │        ┆      ┆          ┆                ┆               ┆        ┆ Abdullah      ┆             │
# │ 1999   ┆ CLE  ┆ LB       ┆ OLB            ┆ 55            ┆ ACT    ┆ Rahim         ┆ Rahim       │
# │        ┆      ┆          ┆                ┆               ┆        ┆ Abdullah      ┆             │
# │ 1999   ┆ TB   ┆ DB       ┆ CB             ┆ 21            ┆ ACT    ┆ Donnie        ┆ Nathaniel   │
# │        ┆      ┆          ┆                ┆               ┆        ┆ Abraham       ┆             │
# │ 1999   ┆ DET  ┆ DB       ┆ DB             ┆ 24            ┆ RES    ┆ Kevin Abrams  ┆ Kevin       │
# │ 1999   ┆ NO   ┆ OL       ┆ G              ┆ 69            ┆ ACT    ┆ Tom Ackerman  ┆ Thomas      │
# │ 1999   ┆ DAL  ┆ OL       ┆ OT             ┆ 76            ┆ ACT    ┆ Flozell Adams ┆ Flozell     │
# │ 1999   ┆ SEA  ┆ DL       ┆ DT             ┆ 98            ┆ ACT    ┆ Sam Adams     ┆ Samuel      │
# │ 1999   ┆ DAL  ┆ DB       ┆ DB             ┆ 24            ┆ ACT    ┆ Vashone Adams ┆ Vashone     │
# └────────┴──────┴──────────┴────────────────┴───────────────┴────────┴───────────────┴─────────────┘
#
# ==================================================
#
# 📊 DATASET: SCHEDULES
# --------------------------------------------------
#
# 🔍 Loading sample from: bronze/schedules/load_date=2025-09-28/schedules_all_seasons.parquet
#   ✅ Total rows: 7,263
#   ✅ Total columns: 46
#   ✅ Estimated size: 2.3 MB
#
#   📋 COLUMNS (46):
#     • game_id: String
#     • season: Int64
#     • game_type: String
#     • week: Int64
#     • gameday: String
#     • weekday: String
#     • gametime: String
#     • away_team: String
#     • away_score: Int64
#     • home_team: String
#     ... and 36 more columns
#
#   📊 SAMPLE DATA (top 10 rows):
#     (Showing first 8 of 46 columns)
# shape: (10, 8)
# ┌─────────────────┬────────┬───────────┬──────┬────────────┬─────────┬──────────┬───────────┐
# │ game_id         ┆ season ┆ game_type ┆ week ┆ gameday    ┆ weekday ┆ gametime ┆ away_team │
# │ ---             ┆ ---    ┆ ---       ┆ ---  ┆ ---        ┆ ---     ┆ ---      ┆ ---       │
# │ str             ┆ i64    ┆ str       ┆ i64  ┆ str        ┆ str     ┆ str      ┆ str       │
# ╞═════════════════╪════════╪═══════════╪══════╪════════════╪═════════╪══════════╪═══════════╡
# │ 1999_01_MIN_ATL ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ MIN       │
# │ 1999_01_KC_CHI  ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ KC        │
# │ 1999_01_PIT_CLE ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ PIT       │
# │ 1999_01_OAK_GB  ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ OAK       │
# │ 1999_01_BUF_IND ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ BUF       │
# │ 1999_01_SF_JAX  ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ SF        │
# │ 1999_01_CAR_NO  ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ CAR       │
# │ 1999_01_NE_NYJ  ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ NE        │
# │ 1999_01_ARI_PHI ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ ARI       │
# │ 1999_01_DET_SEA ┆ 1999   ┆ REG       ┆ 1    ┆ 1999-09-12 ┆ Sunday  ┆ null     ┆ DET       │
# └─────────────────┴────────┴───────────┴──────┴────────────┴─────────┴──────────┴───────────┘
#
# ==================================================
#
# 📊 DATASET: TEAM_STATS
# --------------------------------------------------
#
# 🔍 Loading sample from: bronze/team_stats/load_date=2025-09-28/team_stats.parquet
#   ✅ Total rows: 14,059
#   ✅ Total columns: 102
#   ✅ Estimated size: 5.8 MB
#
#   📋 COLUMNS (102):
#     • season: Int32
#     • week: Int32
#     • team: String
#     • season_type: String
#     • opponent_team: String
#     • completions: Int32
#     • attempts: Int32
#     • passing_yards: Int32
#     • passing_tds: Int32
#     • passing_interceptions: Int32
#     ... and 92 more columns
#
#   📊 SAMPLE DATA (top 10 rows):
#     (Showing first 8 of 102 columns)
# shape: (10, 8)
# ┌────────┬──────┬──────┬─────────────┬───────────────┬─────────────┬──────────┬───────────────┐
# │ season ┆ week ┆ team ┆ season_type ┆ opponent_team ┆ completions ┆ attempts ┆ passing_yards │
# │ ---    ┆ ---  ┆ ---  ┆ ---         ┆ ---           ┆ ---         ┆ ---      ┆ ---           │
# │ i32    ┆ i32  ┆ str  ┆ str         ┆ str           ┆ i32         ┆ i32      ┆ i32           │
# ╞════════╪══════╪══════╪═════════════╪═══════════════╪═════════════╪══════════╪═══════════════╡
# │ 1999   ┆ 1    ┆ ARI  ┆ REG         ┆ PHI           ┆ 25          ┆ 48       ┆ 274           │
# │ 1999   ┆ 1    ┆ ATL  ┆ REG         ┆ MIN           ┆ 18          ┆ 31       ┆ 290           │
# │ 1999   ┆ 1    ┆ BUF  ┆ REG         ┆ IND           ┆ 22          ┆ 42       ┆ 300           │
# │ 1999   ┆ 1    ┆ CAR  ┆ REG         ┆ NO            ┆ 16          ┆ 32       ┆ 207           │
# │ 1999   ┆ 1    ┆ CHI  ┆ REG         ┆ KC            ┆ 31          ┆ 47       ┆ 322           │
# │ 1999   ┆ 1    ┆ CIN  ┆ REG         ┆ TEN           ┆ 20          ┆ 34       ┆ 197           │
# │ 1999   ┆ 1    ┆ CLE  ┆ REG         ┆ PIT           ┆ 6           ┆ 16       ┆ 52            │
# │ 1999   ┆ 1    ┆ DAL  ┆ REG         ┆ WAS           ┆ 28          ┆ 49       ┆ 362           │
# │ 1999   ┆ 1    ┆ DEN  ┆ REG         ┆ MIA           ┆ 24          ┆ 40       ┆ 270           │
# │ 1999   ┆ 1    ┆ DET  ┆ REG         ┆ SEA           ┆ 16          ┆ 26       ┆ 216           │
# └────────┴──────┴──────┴─────────────┴───────────────┴─────────────┴──────────┴───────────────┘
#
# ==================================================
#
# 📈 SUMMARY:
# ==================================================
# ✅ Successfully loaded 7 datasets
# 📊 Total records across all datasets: 1,823,576
# 💾 Total estimated size: 3729.3 MB
#
# 📋 Dataset breakdown:
#   • fantasy_ids: 12,133 rows, 35 cols, 3.4 MB
#   • play_by_play: 1,239,309 rows, 372 cols, 3425.5 MB
#   • player_stats: 460,089 rows, 114 cols, 265.1 MB
#   • players: 24,311 rows, 39 cols, 7.5 MB
#   • rosters: 66,412 rows, 36 cols, 19.8 MB
#   • schedules: 7,263 rows, 46 cols, 2.3 MB
#   • team_stats: 14,059 rows, 102 cols, 5.8 MB
#
# 🎯 Ready for silver layer processing!
#
# ================================================================================
# 📊 DETAILED DATASET OVERVIEW
# ================================================================================
#
# 🏈 FANTASY_IDS
# ------------------------------------------------------------
# 📏 Shape: 12,133 rows × 35 columns
# 📁 Path: bronze/fantasy_ids/load_date=2025-09-28/ff_playerids.parquet
#
# 📋 COLUMNS (35):
#    1. mfl_id                         | Int64
#    2. sportradar_id                  | String
#    3. fantasypros_id                 | Int64
#    4. gsis_id                        | String
#    5. pff_id                         | Int64
#    6. sleeper_id                     | Int64
#    7. nfl_id                         | Int64
#    8. espn_id                        | Int64
#    9. yahoo_id                       | String
#   10. fleaflicker_id                 | String
#   11. cbs_id                         | Int64
#   12. pfr_id                         | String
#   13. cfbref_id                      | String
#   14. rotowire_id                    | Int64
#   15. rotoworld_id                   | String
#   16. ktc_id                         | Int64
#   17. stats_id                       | Int64
#   18. stats_global_id                | Int64
#   19. fantasy_data_id                | String
#   20. swish_id                       | String
#   21. name                           | String
#   22. merge_name                     | String
#   23. position                       | String
#   24. team                           | String
#   25. birthdate                      | String
#   26. age                            | Float64
#   27. draft_year                     | Int64
#   28. draft_round                    | Int64
#   29. draft_pick                     | Int64
#   30. draft_ovr                      | Int64
#   31. twitter_username               | String
#   32. height                         | Int64
#   33. weight                         | Int64
#   34. college                        | String
#   35. db_season                      | Int64
#
# 📊 SAMPLE DATA (first 3 rows):
#     (Showing 35 columns)
# shape: (3, 35)
# ┌────────┬──────────────┬──────────────┬────────────┬───┬────────┬────────┬────────────┬───────────┐
# │ mfl_id ┆ sportradar_i ┆ fantasypros_ ┆ gsis_id    ┆ … ┆ height ┆ weight ┆ college    ┆ db_season │
# │ ---    ┆ d            ┆ id           ┆ ---        ┆   ┆ ---    ┆ ---    ┆ ---        ┆ ---       │
# │ i64    ┆ ---          ┆ ---          ┆ str        ┆   ┆ i64    ┆ i64    ┆ str        ┆ i64       │
# │        ┆ str          ┆ i64          ┆            ┆   ┆        ┆        ┆            ┆           │
# ╞════════╪══════════════╪══════════════╪════════════╪═══╪════════╪════════╪════════════╪═══════════╡
# │ 17030  ┆ 3c76cab3-3df ┆ 24755        ┆ 00-0040676 ┆ … ┆ 74     ┆ 219    ┆ Miami (FL) ┆ 2025      │
# │        ┆ 2-43dd-acaa- ┆              ┆            ┆   ┆        ┆        ┆            ┆           │
# │        ┆ 57e055…      ┆              ┆            ┆   ┆        ┆        ┆            ┆           │
# │ 17031  ┆ 270e09bc-8bf ┆ 25968        ┆ 00-0040668 ┆ … ┆ 74     ┆ 212    ┆ Colorado   ┆ 2025      │
# │        ┆ 8-44b0-87ed- ┆              ┆            ┆   ┆        ┆        ┆            ┆           │
# │        ┆ 1fd014…      ┆              ┆            ┆   ┆        ┆        ┆            ┆           │
# │ 17032  ┆ 53848cba-bca ┆ 23160        ┆ 00-0040691 ┆ … ┆ 74     ┆ 223    ┆ Ole Miss   ┆ 2025      │
# │        ┆ d-4cd0-bb35- ┆              ┆            ┆   ┆        ┆        ┆            ┆           │
# │        ┆ 0a1f6e…      ┆              ┆            ┆   ┆        ┆        ┆            ┆           │
# └────────┴──────────────┴──────────────┴────────────┴───┴────────┴────────┴────────────┴───────────┘
#
# ================================================================================
#
# 🏈 PLAY_BY_PLAY
# ------------------------------------------------------------
# 📏 Shape: 1,239,309 rows × 372 columns
# 📁 Path: bronze/play_by_play/load_date=2025-09-28/pbp_all_seasons.parquet
#
# 📋 COLUMNS (372):
#    1. play_id                        | Float64
#    2. game_id                        | String
#    3. old_game_id                    | String
#    4. home_team                      | String
#    5. away_team                      | String
#    6. season_type                    | String
#    7. week                           | Int32
#    8. posteam                        | String
#    9. posteam_type                   | String
#   10. defteam                        | String
#   11. side_of_field                  | String
#   12. yardline_100                   | Float64
#   13. game_date                      | String
#   14. quarter_seconds_remaining      | Float64
#   15. half_seconds_remaining         | Float64
#   16. game_seconds_remaining         | Float64
#   17. game_half                      | String
#   18. quarter_end                    | Float64
#   19. drive                          | Float64
#   20. sp                             | Float64
#   21. qtr                            | Float64
#   22. down                           | Float64
#   23. goal_to_go                     | Float64
#   24. time                           | String
#   25. yrdln                          | String
#   26. ydstogo                        | Float64
#   27. ydsnet                         | Float64
#   28. desc                           | String
#   29. play_type                      | String
#   30. yards_gained                   | Float64
#   31. shotgun                        | Float64
#   32. no_huddle                      | Float64
#   33. qb_dropback                    | Float64
#   34. qb_kneel                       | Float64
#   35. qb_spike                       | Float64
#   36. qb_scramble                    | Float64
#   37. pass_length                    | String
#   38. pass_location                  | String
#   39. air_yards                      | Float64
#   40. yards_after_catch              | Float64
#   41. run_location                   | String
#   42. run_gap                        | String
#   43. field_goal_result              | String
#   44. kick_distance                  | Float64
#   45. extra_point_result             | String
#   46. two_point_conv_result          | String
#   47. home_timeouts_remaining        | Float64
#   48. away_timeouts_remaining        | Float64
#   49. timeout                        | Float64
#   50. timeout_team                   | String
#   51. td_team                        | String
#   52. td_player_name                 | String
#   53. td_player_id                   | String
#   54. posteam_timeouts_remaining     | Float64
#   55. defteam_timeouts_remaining     | Float64
#   56. total_home_score               | Float64
#   57. total_away_score               | Float64
#   58. posteam_score                  | Float64
#   59. defteam_score                  | Float64
#   60. score_differential             | Float64
#   61. posteam_score_post             | Float64
#   62. defteam_score_post             | Float64
#   63. score_differential_post        | Float64
#   64. no_score_prob                  | Float64
#   65. opp_fg_prob                    | Float64
#   66. opp_safety_prob                | Float64
#   67. opp_td_prob                    | Float64
#   68. fg_prob                        | Float64
#   69. safety_prob                    | Float64
#   70. td_prob                        | Float64
#   71. extra_point_prob               | Float64
#   72. two_point_conversion_prob      | Float64
#   73. ep                             | Float64
#   74. epa                            | Float64
#   75. total_home_epa                 | Float64
#   76. total_away_epa                 | Float64
#   77. total_home_rush_epa            | Float64
#   78. total_away_rush_epa            | Float64
#   79. total_home_pass_epa            | Float64
#   80. total_away_pass_epa            | Float64
#   81. air_epa                        | Float64
#   82. yac_epa                        | Float64
#   83. comp_air_epa                   | Float64
#   84. comp_yac_epa                   | Float64
#   85. total_home_comp_air_epa        | Float64
#   86. total_away_comp_air_epa        | Float64
#   87. total_home_comp_yac_epa        | Float64
#   88. total_away_comp_yac_epa        | Float64
#   89. total_home_raw_air_epa         | Float64
#   90. total_away_raw_air_epa         | Float64
#   91. total_home_raw_yac_epa         | Float64
#   92. total_away_raw_yac_epa         | Float64
#   93. wp                             | Float64
#   94. def_wp                         | Float64
#   95. home_wp                        | Float64
#   96. away_wp                        | Float64
#   97. wpa                            | Float64
#   98. vegas_wpa                      | Float64
#   99. vegas_home_wpa                 | Float64
#   100. home_wp_post                   | Float64
#   101. away_wp_post                   | Float64
#   102. vegas_wp                       | Float64
#   103. vegas_home_wp                  | Float64
#   104. total_home_rush_wpa            | Float64
#   105. total_away_rush_wpa            | Float64
#   106. total_home_pass_wpa            | Float64
#   107. total_away_pass_wpa            | Float64
#   108. air_wpa                        | Float64
#   109. yac_wpa                        | Float64
#   110. comp_air_wpa                   | Float64
#   111. comp_yac_wpa                   | Float64
#   112. total_home_comp_air_wpa        | Float64
#   113. total_away_comp_air_wpa        | Float64
#   114. total_home_comp_yac_wpa        | Float64
#   115. total_away_comp_yac_wpa        | Float64
#   116. total_home_raw_air_wpa         | Float64
#   117. total_away_raw_air_wpa         | Float64
#   118. total_home_raw_yac_wpa         | Float64
#   119. total_away_raw_yac_wpa         | Float64
#   120. punt_blocked                   | Float64
#   121. first_down_rush                | Float64
#   122. first_down_pass                | Float64
#   123. first_down_penalty             | Float64
#   124. third_down_converted           | Float64
#   125. third_down_failed              | Float64
#   126. fourth_down_converted          | Float64
#   127. fourth_down_failed             | Float64
#   128. incomplete_pass                | Float64
#   129. touchback                      | Float64
#   130. interception                   | Float64
#   131. punt_inside_twenty             | Float64
#   132. punt_in_endzone                | Float64
#   133. punt_out_of_bounds             | Float64
#   134. punt_downed                    | Float64
#   135. punt_fair_catch                | Float64
#   136. kickoff_inside_twenty          | Float64
#   137. kickoff_in_endzone             | Float64
#   138. kickoff_out_of_bounds          | Float64
#   139. kickoff_downed                 | Float64
#   140. kickoff_fair_catch             | Float64
#   141. fumble_forced                  | Float64
#   142. fumble_not_forced              | Float64
#   143. fumble_out_of_bounds           | Float64
#   144. solo_tackle                    | Float64
#   145. safety                         | Float64
#   146. penalty                        | Float64
#   147. tackled_for_loss               | Float64
#   148. fumble_lost                    | Float64
#   149. own_kickoff_recovery           | Float64
#   150. own_kickoff_recovery_td        | Float64
#   151. qb_hit                         | Float64
#   152. rush_attempt                   | Float64
#   153. pass_attempt                   | Float64
#   154. sack                           | Float64
#   155. touchdown                      | Float64
#   156. pass_touchdown                 | Float64
#   157. rush_touchdown                 | Float64
#   158. return_touchdown               | Float64
#   159. extra_point_attempt            | Float64
#   160. two_point_attempt              | Float64
#   161. field_goal_attempt             | Float64
#   162. kickoff_attempt                | Float64
#   163. punt_attempt                   | Float64
#   164. fumble                         | Float64
#   165. complete_pass                  | Float64
#   166. assist_tackle                  | Float64
#   167. lateral_reception              | Float64
#   168. lateral_rush                   | Float64
#   169. lateral_return                 | Float64
#   170. lateral_recovery               | Float64
#   171. passer_player_id               | String
#   172. passer_player_name             | String
#   173. passing_yards                  | Float64
#   174. receiver_player_id             | String
#   175. receiver_player_name           | String
#   176. receiving_yards                | Float64
#   177. rusher_player_id               | String
#   178. rusher_player_name             | String
#   179. rushing_yards                  | Float64
#   180. lateral_receiver_player_id     | String
#   181. lateral_receiver_player_name   | String
#   182. lateral_receiving_yards        | Float64
#   183. lateral_rusher_player_id       | String
#   184. lateral_rusher_player_name     | String
#   185. lateral_rushing_yards          | Float64
#   186. lateral_sack_player_id         | String
#   187. lateral_sack_player_name       | String
#   188. interception_player_id         | String
#   189. interception_player_name       | String
#   190. lateral_interception_player_id | String
#   191. lateral_interception_player_name | String
#   192. punt_returner_player_id        | String
#   193. punt_returner_player_name      | String
#   194. lateral_punt_returner_player_id | String
#   195. lateral_punt_returner_player_name | String
#   196. kickoff_returner_player_name   | String
#   197. kickoff_returner_player_id     | String
#   198. lateral_kickoff_returner_player_id | String
#   199. lateral_kickoff_returner_player_name | String
#   200. punter_player_id               | String
#   201. punter_player_name             | String
#   202. kicker_player_name             | String
#   203. kicker_player_id               | String
#   204. own_kickoff_recovery_player_id | String
#   205. own_kickoff_recovery_player_name | String
#   206. blocked_player_id              | String
#   207. blocked_player_name            | String
#   208. tackle_for_loss_1_player_id    | String
#   209. tackle_for_loss_1_player_name  | String
#   210. tackle_for_loss_2_player_id    | String
#   211. tackle_for_loss_2_player_name  | String
#   212. qb_hit_1_player_id             | String
#   213. qb_hit_1_player_name           | String
#   214. qb_hit_2_player_id             | String
#   215. qb_hit_2_player_name           | String
#   216. forced_fumble_player_1_team    | String
#   217. forced_fumble_player_1_player_id | String
#   218. forced_fumble_player_1_player_name | String
#   219. forced_fumble_player_2_team    | String
#   220. forced_fumble_player_2_player_id | String
#   221. forced_fumble_player_2_player_name | String
#   222. solo_tackle_1_team             | String
#   223. solo_tackle_2_team             | String
#   224. solo_tackle_1_player_id        | String
#   225. solo_tackle_2_player_id        | String
#   226. solo_tackle_1_player_name      | String
#   227. solo_tackle_2_player_name      | String
#   228. assist_tackle_1_player_id      | String
#   229. assist_tackle_1_player_name    | String
#   230. assist_tackle_1_team           | String
#   231. assist_tackle_2_player_id      | String
#   232. assist_tackle_2_player_name    | String
#   233. assist_tackle_2_team           | String
#   234. assist_tackle_3_player_id      | String
#   235. assist_tackle_3_player_name    | String
#   236. assist_tackle_3_team           | String
#   237. assist_tackle_4_player_id      | String
#   238. assist_tackle_4_player_name    | String
#   239. assist_tackle_4_team           | String
#   240. tackle_with_assist             | Float64
#   241. tackle_with_assist_1_player_id | String
#   242. tackle_with_assist_1_player_name | String
#   243. tackle_with_assist_1_team      | String
#   244. tackle_with_assist_2_player_id | String
#   245. tackle_with_assist_2_player_name | String
#   246. tackle_with_assist_2_team      | String
#   247. pass_defense_1_player_id       | String
#   248. pass_defense_1_player_name     | String
#   249. pass_defense_2_player_id       | String
#   250. pass_defense_2_player_name     | String
#   251. fumbled_1_team                 | String
#   252. fumbled_1_player_id            | String
#   253. fumbled_1_player_name          | String
#   254. fumbled_2_player_id            | String
#   255. fumbled_2_player_name          | String
#   256. fumbled_2_team                 | String
#   257. fumble_recovery_1_team         | String
#   258. fumble_recovery_1_yards        | Float64
#   259. fumble_recovery_1_player_id    | String
#   260. fumble_recovery_1_player_name  | String
#   261. fumble_recovery_2_team         | String
#   262. fumble_recovery_2_yards        | Float64
#   263. fumble_recovery_2_player_id    | String
#   264. fumble_recovery_2_player_name  | String
#   265. sack_player_id                 | String
#   266. sack_player_name               | String
#   267. half_sack_1_player_id          | String
#   268. half_sack_1_player_name        | String
#   269. half_sack_2_player_id          | String
#   270. half_sack_2_player_name        | String
#   271. return_team                    | String
#   272. return_yards                   | Float64
#   273. penalty_team                   | String
#   274. penalty_player_id              | String
#   275. penalty_player_name            | String
#   276. penalty_yards                  | Float64
#   277. replay_or_challenge            | Float64
#   278. replay_or_challenge_result     | String
#   279. penalty_type                   | String
#   280. defensive_two_point_attempt    | Float64
#   281. defensive_two_point_conv       | Float64
#   282. defensive_extra_point_attempt  | Float64
#   283. defensive_extra_point_conv     | Float64
#   284. safety_player_name             | String
#   285. safety_player_id               | String
#   286. season                         | Int32
#   287. cp                             | Float64
#   288. cpoe                           | Float64
#   289. series                         | Float64
#   290. series_success                 | Float64
#   291. series_result                  | String
#   292. order_sequence                 | Float64
#   293. start_time                     | String
#   294. time_of_day                    | String
#   295. stadium                        | String
#   296. weather                        | String
#   297. nfl_api_id                     | String
#   298. play_clock                     | String
#   299. play_deleted                   | Float64
#   300. play_type_nfl                  | String
#   301. special_teams_play             | Float64
#   302. st_play_type                   | String
#   303. end_clock_time                 | String
#   304. end_yard_line                  | String
#   305. fixed_drive                    | Float64
#   306. fixed_drive_result             | String
#   307. drive_real_start_time          | String
#   308. drive_play_count               | Float64
#   309. drive_time_of_possession       | String
#   310. drive_first_downs              | Float64
#   311. drive_inside20                 | Float64
#   312. drive_ended_with_score         | Float64
#   313. drive_quarter_start            | Float64
#   314. drive_quarter_end              | Float64
#   315. drive_yards_penalized          | Float64
#   316. drive_start_transition         | String
#   317. drive_end_transition           | String
#   318. drive_game_clock_start         | String
#   319. drive_game_clock_end           | String
#   320. drive_start_yard_line          | String
#   321. drive_end_yard_line            | String
#   322. drive_play_id_started          | Float64
#   323. drive_play_id_ended            | Float64
#   324. away_score                     | Int32
#   325. home_score                     | Int32
#   326. location                       | String
#   327. result                         | Int32
#   328. total                          | Int32
#   329. spread_line                    | Float64
#   330. total_line                     | Float64
#   331. div_game                       | Int32
#   332. roof                           | String
#   333. surface                        | String
#   334. temp                           | Int32
#   335. wind                           | Int32
#   336. home_coach                     | String
#   337. away_coach                     | String
#   338. stadium_id                     | String
#   339. game_stadium                   | String
#   340. aborted_play                   | Float64
#   341. success                        | Float64
#   342. passer                         | String
#   343. passer_jersey_number           | Int32
#   344. rusher                         | String
#   345. rusher_jersey_number           | Int32
#   346. receiver                       | String
#   347. receiver_jersey_number         | Int32
#   348. pass                           | Float64
#   349. rush                           | Float64
#   350. first_down                     | Float64
#   351. special                        | Float64
#   352. play                           | Float64
#   353. passer_id                      | String
#   354. rusher_id                      | String
#   355. receiver_id                    | String
#   356. name                           | String
#   357. jersey_number                  | Int32
#   358. id                             | String
#   359. fantasy_player_name            | String
#   360. fantasy_player_id              | String
#   361. fantasy                        | String
#   362. fantasy_id                     | String
#   363. out_of_bounds                  | Float64
#   364. home_opening_kickoff           | Float64
#   365. qb_epa                         | Float64
#   366. xyac_epa                       | Float64
#   367. xyac_mean_yardage              | Float64
#   368. xyac_median_yardage            | Float64
#   369. xyac_success                   | Float64
#   370. xyac_fd                        | Float64
#   371. xpass                          | Float64
#   372. pass_oe                        | Float64
#
# 📊 SAMPLE DATA (first 3 rows):
#     (Showing 372 columns)
# shape: (3, 372)
# ┌─────────┬───────────────┬─────────────┬───────────┬───┬──────────────┬─────────┬───────┬─────────┐
# │ play_id ┆ game_id       ┆ old_game_id ┆ home_team ┆ … ┆ xyac_success ┆ xyac_fd ┆ xpass ┆ pass_oe │
# │ ---     ┆ ---           ┆ ---         ┆ ---       ┆   ┆ ---          ┆ ---     ┆ ---   ┆ ---     │
# │ f64     ┆ str           ┆ str         ┆ str       ┆   ┆ f64          ┆ f64     ┆ f64   ┆ f64     │
# ╞═════════╪═══════════════╪═════════════╪═══════════╪═══╪══════════════╪═════════╪═══════╪═════════╡
# │ 35.0    ┆ 1999_01_ARI_P ┆ 1999091200  ┆ PHI       ┆ … ┆ null         ┆ null    ┆ null  ┆ null    │
# │         ┆ HI            ┆             ┆           ┆   ┆              ┆         ┆       ┆         │
# │ 60.0    ┆ 1999_01_ARI_P ┆ 1999091200  ┆ PHI       ┆ … ┆ null         ┆ null    ┆ null  ┆ null    │
# │         ┆ HI            ┆             ┆           ┆   ┆              ┆         ┆       ┆         │
# │ 82.0    ┆ 1999_01_ARI_P ┆ 1999091200  ┆ PHI       ┆ … ┆ null         ┆ null    ┆ null  ┆ null    │
# │         ┆ HI            ┆             ┆           ┆   ┆              ┆         ┆       ┆         │
# └─────────┴───────────────┴─────────────┴───────────┴───┴──────────────┴─────────┴───────┴─────────┘
#
# ================================================================================
#
# 🏈 PLAYER_STATS
# ------------------------------------------------------------
# 📏 Shape: 460,089 rows × 114 columns
# 📁 Path: bronze/player_stats/load_date=2025-09-28/player_stats_all_seasons.parquet
#
# 📋 COLUMNS (114):
#    1. player_id                      | String
#    2. player_name                    | String
#    3. player_display_name            | String
#    4. position                       | String
#    5. position_group                 | String
#    6. headshot_url                   | String
#    7. season                         | Int32
#    8. week                           | Int32
#    9. season_type                    | String
#   10. team                           | String
#   11. opponent_team                  | String
#   12. completions                    | Int32
#   13. attempts                       | Int32
#   14. passing_yards                  | Int32
#   15. passing_tds                    | Int32
#   16. passing_interceptions          | Int32
#   17. sacks_suffered                 | Int32
#   18. sack_yards_lost                | Int32
#   19. sack_fumbles                   | Int32
#   20. sack_fumbles_lost              | Int32
#   21. passing_air_yards              | Int32
#   22. passing_yards_after_catch      | Int32
#   23. passing_first_downs            | Int32
#   24. passing_epa                    | Float64
#   25. passing_cpoe                   | Float64
#   26. passing_2pt_conversions        | Int32
#   27. pacr                           | Float64
#   28. carries                        | Int32
#   29. rushing_yards                  | Int32
#   30. rushing_tds                    | Int32
#   31. rushing_fumbles                | Int32
#   32. rushing_fumbles_lost           | Int32
#   33. rushing_first_downs            | Int32
#   34. rushing_epa                    | Float64
#   35. rushing_2pt_conversions        | Int32
#   36. receptions                     | Int32
#   37. targets                        | Int32
#   38. receiving_yards                | Int32
#   39. receiving_tds                  | Int32
#   40. receiving_fumbles              | Int32
#   41. receiving_fumbles_lost         | Int32
#   42. receiving_air_yards            | Int32
#   43. receiving_yards_after_catch    | Int32
#   44. receiving_first_downs          | Int32
#   45. receiving_epa                  | Float64
#   46. receiving_2pt_conversions      | Int32
#   47. racr                           | Float64
#   48. target_share                   | Float64
#   49. air_yards_share                | Float64
#   50. wopr                           | Float64
#   51. special_teams_tds              | Int32
#   52. def_tackles_solo               | Int32
#   53. def_tackles_with_assist        | Int32
#   54. def_tackle_assists             | Int32
#   55. def_tackles_for_loss           | Int32
#   56. def_tackles_for_loss_yards     | Int32
#   57. def_fumbles_forced             | Int32
#   58. def_sacks                      | Float64
#   59. def_sack_yards                 | Float64
#   60. def_qb_hits                    | Int32
#   61. def_interceptions              | Int32
#   62. def_interception_yards         | Int32
# ...
#    5. last_name                      | String
#    6. short_name                     | String
#    7. football_name                  | String
#    8. suffix                         | String
#    9. esb_id                         | String
#   10. nfl_id                         | String
#   11. pfr_id                         | String
#   12. pff_id                         | String
#   13. otc_id                         | String
#   14. espn_id                        | String
#   15. smart_id                       | String
#   16. birth_date                     | String
#   17. position_group                 | String
#   18. position                       | String
#   19. ngs_position_group             | String
#   20. ngs_position                   | String
#   21. height                         | Int32
#   22. weight                         | Int32
#   23. headshot                       | String
#   24. college_name                   | String
#   25. college_conference             | String
#   26. jersey_number                  | String
#   27. rookie_season                  | Int32
#   28. last_season                    | Int32
#   29. latest_team                    | String
#   30. status                         | String
#   31. ngs_status                     | String
#   32. ngs_status_short_description   | String
#   33. years_of_experience            | Int32
#   34. pff_position                   | String
#   35. pff_status                     | String
#   36. draft_year                     | Int32
#   37. draft_round                    | Int32
#   38. draft_pick                     | Int32
#   39. draft_team                     | String
#
# 📊 SAMPLE DATA (first 3 rows):
#     (Showing 39 columns)
# shape: (3, 39)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ gsis_id   ┆ display_n ┆ common_fi ┆ first_nam ┆ … ┆ draft_yea ┆ draft_rou ┆ draft_pic ┆ draft_te │
# │ ---       ┆ ame       ┆ rst_name  ┆ e         ┆   ┆ r         ┆ nd        ┆ k         ┆ am       │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ str       ┆ str       ┆ str       ┆   ┆ i32       ┆ i32       ┆ i32       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 00-002883 ┆ Isaako    ┆ Isaako    ┆ Isaako    ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 0         ┆ Aaitui    ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00-003838 ┆ Israel    ┆ Israel    ┆ Israel    ┆ … ┆ 2023      ┆ 5         ┆ 143       ┆ NYJ      │
# │ 9         ┆ Abanikand ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ a         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00-002464 ┆ Jon       ┆ Jon       ┆ Jon       ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 4         ┆ Abbate    ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# ================================================================================
#
# 🏈 ROSTERS
# ------------------------------------------------------------
# 📏 Shape: 66,412 rows × 36 columns
# 📁 Path: bronze/rosters/load_date=2025-09-28/rosters_all_seasons.parquet
#
# 📋 COLUMNS (36):
#    1. season                         | Int32
#    2. team                           | String
#    3. position                       | String
#    4. depth_chart_position           | String
#    5. jersey_number                  | String
#    6. status                         | String
#    7. full_name                      | String
#    8. first_name                     | String
#    9. last_name                      | String
#   10. birth_date                     | Date
#   11. height                         | Float64
#   12. weight                         | Int32
#   13. college                        | String
#   14. gsis_id                        | String
#   15. espn_id                        | String
#   16. sportradar_id                  | String
#   17. yahoo_id                       | String
#   18. rotowire_id                    | String
#   19. pff_id                         | String
#   20. pfr_id                         | String
#   21. fantasy_data_id                | String
#   22. sleeper_id                     | String
#   23. years_exp                      | Int32
#   24. headshot_url                   | String
#   25. esb_id                         | String
#   26. gsis_it_id                     | String
#   27. smart_id                       | String
#   28. entry_year                     | Int32
#   29. rookie_year                    | Int32
#   30. draft_club                     | String
#   31. ngs_position                   | String
#   32. week                           | Int32
#   33. game_type                      | String
#   34. status_description_abbr        | String
#   35. football_name                  | String
#   36. draft_number                   | String
#
# 📊 SAMPLE DATA (first 3 rows):
#     (Showing 36 columns)
# shape: (3, 36)
# ┌────────┬──────┬──────────┬─────────────┬───┬───────────┬─────────────┬─────────────┬─────────────┐
# │ season ┆ team ┆ position ┆ depth_chart ┆ … ┆ game_type ┆ status_desc ┆ football_na ┆ draft_numbe │
# │ ---    ┆ ---  ┆ ---      ┆ _position   ┆   ┆ ---       ┆ ription_abb ┆ me          ┆ r           │
# │ i32    ┆ str  ┆ str      ┆ ---         ┆   ┆ str       ┆ r           ┆ ---         ┆ ---         │
# │        ┆      ┆          ┆ str         ┆   ┆           ┆ ---         ┆ str         ┆ str         │
# │        ┆      ┆          ┆             ┆   ┆           ┆ str         ┆             ┆             │
# ╞════════╪══════╪══════════╪═════════════╪═══╪═══════════╪═════════════╪═════════════╪═════════════╡
# │ 1999   ┆ CLE  ┆ RB       ┆ RB          ┆ … ┆ null      ┆ null        ┆ null        ┆ null        │
# │ 1999   ┆ MIA  ┆ RB       ┆ RB          ┆ … ┆ null      ┆ null        ┆ null        ┆ null        │
# │ 1999   ┆ TB   ┆ RB       ┆ RB          ┆ … ┆ null      ┆ null        ┆ null        ┆ null        │
# └────────┴──────┴──────────┴─────────────┴───┴───────────┴─────────────┴─────────────┴─────────────┘
#
# ================================================================================
#
# 🏈 SCHEDULES
# ------------------------------------------------------------
# 📏 Shape: 7,263 rows × 46 columns
# 📁 Path: bronze/schedules/load_date=2025-09-28/schedules_all_seasons.parquet
#
# 📋 COLUMNS (46):
#    1. game_id                        | String
#    2. season                         | Int64
#    3. game_type                      | String
#    4. week                           | Int64
#    5. gameday                        | String
#    6. weekday                        | String
#    7. gametime                       | String
#    8. away_team                      | String
#    9. away_score                     | Int64
#   10. home_team                      | String
#   11. home_score                     | Int64
#   12. location                       | String
#   13. result                         | Int64
#   14. total                          | Int64
#   15. overtime                       | Int64
#   16. old_game_id                    | Int64
#   17. gsis                           | Int64
#   18. nfl_detail_id                  | String
#   19. pfr                            | String
#   20. pff                            | String
#   21. espn                           | Int64
#   22. ftn                            | String
#   23. away_rest                      | Int64
#   24. home_rest                      | Int64
#   25. away_moneyline                 | String
#   26. home_moneyline                 | String
#   27. spread_line                    | Float64
#   28. away_spread_odds               | String
#   29. home_spread_odds               | String
#   30. total_line                     | Float64
#   31. under_odds                     | String
#   32. over_odds                      | String
#   33. div_game                       | Int64
#   34. roof                           | String
#   35. surface                        | String
#   36. temp                           | Int64
#   37. wind                           | Int64
#   38. away_qb_id                     | String
#   39. home_qb_id                     | String
#   40. away_qb_name                   | String
#   41. home_qb_name                   | String
#   42. away_coach                     | String
#   43. home_coach                     | String
#   44. referee                        | String
#   45. stadium_id                     | String
#   46. stadium                        | String
#
# 📊 SAMPLE DATA (first 3 rows):
#     (Showing 46 columns)
# shape: (3, 46)
# ┌──────────────┬────────┬───────────┬──────┬───┬──────────────┬─────────┬────────────┬─────────────┐
# │ game_id      ┆ season ┆ game_type ┆ week ┆ … ┆ home_coach   ┆ referee ┆ stadium_id ┆ stadium     │
# │ ---          ┆ ---    ┆ ---       ┆ ---  ┆   ┆ ---          ┆ ---     ┆ ---        ┆ ---         │
# │ str          ┆ i64    ┆ str       ┆ i64  ┆   ┆ str          ┆ str     ┆ str        ┆ str         │
# ╞══════════════╪════════╪═══════════╪══════╪═══╪══════════════╪═════════╪════════════╪═════════════╡
# │ 1999_01_MIN_ ┆ 1999   ┆ REG       ┆ 1    ┆ … ┆ Dan Reeves   ┆ Gerry   ┆ ATL00      ┆ Georgia     │
# │ ATL          ┆        ┆           ┆      ┆   ┆              ┆ Austin  ┆            ┆ Dome        │
# │ 1999_01_KC_C ┆ 1999   ┆ REG       ┆ 1    ┆ … ┆ Dick Jauron  ┆ Phil    ┆ CHI98      ┆ Soldier     │
# │ HI           ┆        ┆           ┆      ┆   ┆              ┆ Luckett ┆            ┆ Field       │
# │ 1999_01_PIT_ ┆ 1999   ┆ REG       ┆ 1    ┆ … ┆ Chris Palmer ┆ Bob     ┆ CLE00      ┆ Cleveland   │
# │ CLE          ┆        ┆           ┆      ┆   ┆              ┆ McElwee ┆            ┆ Browns      │
# │              ┆        ┆           ┆      ┆   ┆              ┆         ┆            ┆ Stadium     │
# └──────────────┴────────┴───────────┴──────┴───┴──────────────┴─────────┴────────────┴─────────────┘
#
# ================================================================================
#
# 🏈 TEAM_STATS
# ------------------------------------------------------------
# 📏 Shape: 14,059 rows × 102 columns
# 📁 Path: bronze/team_stats/load_date=2025-09-28/team_stats.parquet
#
# 📋 COLUMNS (102):
#    1. season                         | Int32
#    2. week                           | Int32
#    3. team                           | String
#    4. season_type                    | String
#    5. opponent_team                  | String
#    6. completions                    | Int32
#    7. attempts                       | Int32
#    8. passing_yards                  | Int32
#    9. passing_tds                    | Int32
#   10. passing_interceptions          | Int32
#   11. sacks_suffered                 | Int32
#   12. sack_yards_lost                | Int32
#   13. sack_fumbles                   | Int32
#   14. sack_fumbles_lost              | Int32
#   15. passing_air_yards              | Int32
#   16. passing_yards_after_catch      | Int32
#   17. passing_first_downs            | Int32
#   18. passing_epa                    | Float64
#   19. passing_cpoe                   | Float64
#   20. passing_2pt_conversions        | Int32
#   21. carries                        | Int32
#   22. rushing_yards                  | Int32
#   23. rushing_tds                    | Int32
#   24. rushing_fumbles                | Int32
#   25. rushing_fumbles_lost           | Int32
#   26. rushing_first_downs            | Int32
#   27. rushing_epa                    | Float64
#   28. rushing_2pt_conversions        | Int32
#   29. receptions                     | Int32
#   30. targets                        | Int32
#   31. receiving_yards                | Int32
#   32. receiving_tds                  | Int32
#   33. receiving_fumbles              | Int32
#   34. receiving_fumbles_lost         | Int32
#   35. receiving_air_yards            | Int32
#   36. receiving_yards_after_catch    | Int32
#   37. receiving_first_downs          | Int32
#   38. receiving_epa                  | Float64
#   39. receiving_2pt_conversions      | Int32
#   40. special_teams_tds              | Int32
#   41. def_tackles_solo               | Int32
#   42. def_tackles_with_assist        | Int32
#   43. def_tackle_assists             | Int32
#   44. def_tackles_for_loss           | Int32
#   45. def_tackles_for_loss_yards     | Int32
#   46. def_fumbles_forced             | Int32
#   47. def_sacks                      | Float64
#   48. def_sack_yards                 | Float64
#   49. def_qb_hits                    | Int32
#   50. def_interceptions              | Int32
#   51. def_interception_yards         | Int32
#   52. def_pass_defended              | Int32
#   53. def_tds                        | Int32
#   54. def_fumbles                    | Int32
#   55. def_safeties                   | Int32
#   56. misc_yards                     | Int32
#   57. fumble_recovery_own            | Int32
#   58. fumble_recovery_yards_own      | Int32
#   59. fumble_recovery_opp            | Int32
#   60. fumble_recovery_yards_opp      | Int32
#   61. fumble_recovery_tds            | Int32
#   62. penalties                      | Int32
#   63. penalty_yards                  | Int32
#   64. timeouts                       | Int32
#   65. punt_returns                   | Int32
#   66. punt_return_yards              | Int32
#   67. kickoff_returns                | Int32
#   68. kickoff_return_yards           | Int32
#   69. fg_made                        | Int32
#   70. fg_att                         | Int32
#   71. fg_missed                      | Int32
#   72. fg_blocked                     | Int32
#   73. fg_long                        | Int32
#   74. fg_pct                         | Float64
#   75. fg_made_0_19                   | Int32
#   76. fg_made_20_29                  | Int32
#   77. fg_made_30_39                  | Int32
#   78. fg_made_40_49                  | Int32
#   79. fg_made_50_59                  | Int32
#   80. fg_made_60_                    | Int32
#   81. fg_missed_0_19                 | Int32
#   82. fg_missed_20_29                | Int32
#   83. fg_missed_30_39                | Int32
#   84. fg_missed_40_49                | Int32
#   85. fg_missed_50_59                | Int32
#   86. fg_missed_60_                  | Int32
#   87. fg_made_list                   | String
#   88. fg_missed_list                 | String
#   89. fg_blocked_list                | String
#   90. fg_made_distance               | Int32
#   91. fg_missed_distance             | Int32
#   92. fg_blocked_distance            | Int32
#   93. pat_made                       | Int32
#   94. pat_att                        | Int32
#   95. pat_missed                     | Int32
#   96. pat_blocked                    | Int32
#   97. pat_pct                        | Float64
#   98. gwfg_made                      | Int32
#   99. gwfg_att                       | Int32
#   100. gwfg_missed                    | Int32
#   101. gwfg_blocked                   | Int32
#   102. gwfg_distance                  | Int32
#
# 📊 SAMPLE DATA (first 3 rows):
#     (Showing 102 columns)
# shape: (3, 102)
# ┌────────┬──────┬──────┬─────────────┬───┬──────────┬─────────────┬──────────────┬───────────────┐
# │ season ┆ week ┆ team ┆ season_type ┆ … ┆ gwfg_att ┆ gwfg_missed ┆ gwfg_blocked ┆ gwfg_distance │
# │ ---    ┆ ---  ┆ ---  ┆ ---         ┆   ┆ ---      ┆ ---         ┆ ---          ┆ ---           │
# │ i32    ┆ i32  ┆ str  ┆ str         ┆   ┆ i32      ┆ i32         ┆ i32          ┆ i32           │
# ╞════════╪══════╪══════╪═════════════╪═══╪══════════╪═════════════╪══════════════╪═══════════════╡
# │ 1999   ┆ 1    ┆ ARI  ┆ REG         ┆ … ┆ 1        ┆ 0           ┆ 0            ┆ 31            │
# │ 1999   ┆ 1    ┆ ATL  ┆ REG         ┆ … ┆ 0        ┆ 0           ┆ 0            ┆ 0             │
# │ 1999   ┆ 1    ┆ BUF  ┆ REG         ┆ … ┆ 0        ┆ 0           ┆ 0            ┆ 0             │
# └────────┴──────┴──────┴─────────────┴───┴──────────┴─────────────┴──────────────┴───────────────┘
#
# ================================================================================
#
# 🚀 Overview complete! All datasets ready for analysis.

# %%
all_dataset_info.keys()
# Out:
# dict_keys(['fantasy_ids', 'play_by_play', 'player_stats', 'players', 'rosters', 'schedules', 'team_stats'])

# %%
for col in all_dataset_info['fantasy_ids']['columns']:
    print(col)
# Out:
# mfl_id
# sportradar_id
# fantasypros_id
# gsis_id
# pff_id
# sleeper_id
# nfl_id
# espn_id
# yahoo_id
# fleaflicker_id
# cbs_id
# pfr_id
# cfbref_id
# rotowire_id
# rotoworld_id
# ktc_id
# stats_id
# stats_global_id
# fantasy_data_id
# swish_id
# name
# merge_name
# position
# team
# birthdate
# age
# draft_year
# draft_round
# draft_pick
# draft_ovr
# twitter_username
# height
# weight
# college
# db_season
