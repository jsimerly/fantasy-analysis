# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import pandas as pd
import numpy as np
import os
import psycopg2
from dotenv import load_dotenv

from models import Player, GameStats, KtcValue
from datetime import datetime
import requests
from bs4 import BeautifulSoup
import time
import random
import re
import json
from tqdm.notebook import tqdm

# %%
load_dotenv()
DB_USERNAME = os.environ['DB_USERNAME']
DB_PASSWORD = os.environ['DB_PASSWORD']
DB_HOST = os.environ['DB_HOST']
DB_PORT = os.environ['DB_PORT']
DB_NAME = os.environ['DB_NAME']

DB_URL = f"postgresql://{DB_USERNAME}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(DB_URL, echo=False)

Session = sessionmaker(bind=engine)
session = Session()

# %%
def fetch_soup(url) -> BeautifulSoup:
    time.sleep(random.uniform(1,5))
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, 'html.parser')
    return soup

def find_value_data(soup) -> list[dict]:
    pattern = re.compile(r'var playerSuperflex', re.MULTILINE | re.DOTALL)
    
    content = soup.find('script', text=pattern)
    content = str(content)
    bottomHalf = content.split("var playerSuperflex = ",1)[1]
    fullCut = bottomHalf.split('var playerOneQB = ',1)[0].strip()
    json_text= fullCut[:-1]
    js = json.loads(json_text)
    data = js['overallValue']
    return data

def scrape(player: Player):
    url = f'https://keeptradecut.com/dynasty-rankings/players/{player.ktc_id}'

    if player:
        player_soup = fetch_soup(url)
        ktc_value_history = find_value_data(player_soup)
        
        for ktc_value in ktc_value_history:
            date = datetime.strptime(ktc_value['d'], '%Y-%m-%d')
            value = int(ktc_value['v'])
            ktc_value_obj = KtcValue(
                player_id = player.id,
                date = date,
                value = value
            )
            session.merge(ktc_value_obj)
        session.commit()
        print(f'{player.display_name} KTC data commited')
        return
    print(f"{player.display_name} not found.")

# %%
ktc_players = session.query(Player).filter(Player.ktc_id.is_not(None)).all()
errors =[]
for player in tqdm(ktc_players, desc='Scraping...'):
    
    try:
        scrape(player)
    except Exception as error:
        print(f"Error with {player.display_name}: {error}")
        errors.append(player)
errors
# Out:
# Scraping...:   0%|          | 0/657 [00:00<?, ?it/s]
# C:\Users\simer\AppData\Local\Temp\ipykernel_26424\339467659.py:10: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   content = soup.find('script', text=pattern)
# Joe Burrow KTC data commited
# Jalen Hurts KTC data commited
# A.T. Perry KTC data commited
# Justin Herbert KTC data commited
# Justin Jefferson KTC data commited
# Bijan Robinson KTC data commited
# Adam Trautman KTC data commited
# Albert Okwuegbunam KTC data commited
# Amari Rodgers KTC data commited
# Anthony Schwartz KTC data commited
# Anthony Richardson KTC data commited
# Bailey Zappe KTC data commited
# Benny Snell KTC data commited
# Bo Melton KTC data commited
# Brenton Strange KTC data commited
# Brock Wright KTC data commited
# Bryan Edwards KTC data commited
# Brycen Hopkins KTC data commited
# C.J. Stroud KTC data commited
# Jordan Love KTC data commited
# Caleb Huntley KTC data commited
# Calvin Austin KTC data commited
# Cam Akers KTC data commited
# Cameron Brate KTC data commited
# Cedrick Wilson KTC data commited
# Charlie Jones KTC data commited
# Chase Claypool KTC data commited
# Chuba Hubbard KTC data commited
# Cole Turner KTC data commited
# Craig Reynolds KTC data commited
# Puka Nacua KTC data commited
# D'Andre Swift KTC data commited
# D'Ernest Johnson KTC data commited
# DK Metcalf KTC data commited
# Dalvin Cook KTC data commited
# Damien Harris KTC data commited
# Danny Gray KTC data commited
# Darnell Washington KTC data commited
# Darrell Henderson KTC data commited
# Davis Allen KTC data commited
# Davis Mills KTC data commited
# DeWayne McBride KTC data commited
# DeeJay Dallas KTC data commited
# Deneric Prince KTC data commited
# Demetric Felton KTC data commited
# Deon Jackson KTC data commited
# Deonte Harty KTC data commited
# Derius Davis KTC data commited
# Deven Thompkins KTC data commited
# Desmond Ridder KTC data commited
# Devon Achane KTC data commited
# Devin Duvernay KTC data commited
# Jahmyr Gibbs KTC data commited
# Donovan Peoples-Jones KTC data commited
# Breece Hall KTC data commited
# Elijah Higgins KTC data commited
# Elijah Mitchell KTC data commited
# Elijah Mitchell KTC data commited
# Elijah Dotson KTC data commited
# Eno Benjamin KTC data commited
# Evan Hull KTC data commited
# Gabe Davis KTC data commited
# Gary Brightwell KTC data commited
# Harrison Bryant KTC data commited
# Henry Ruggs KTC data commited
# Ian Book KTC data commited
# Ihmir Smith-Marsette KTC data commited
# Irv Smith KTC data commited
# Isaiah Spiller KTC data commited
# Israel Abanikanda KTC data commited
# Jacob Eason KTC data commited
# Jacoby Brissett KTC data commited
# Jake Funk KTC data commited
# Jake Browning KTC data commited
# Jake Bobo KTC data commited
# Jake Fromm KTC data commited
# Jalen Guyton KTC data commited
# Jaleel McLaughlin KTC data commited
# Jakobi Meyers KTC data commited
# Jalen Reagor KTC data commited
# Jalen Tolbert KTC data commited
# James Robinson KTC data commited
# James Proche KTC data commited
# James Mitchell KTC data commited
# James White KTC data commited
# Jamycal Hasty KTC data commited
# Jaren Hall KTC data commited
# Jaret Patterson KTC data commited
# Jauan Jennings KTC data commited
# Jaxon Smith-Njigba KTC data commited
# Jaylen Warren KTC data commited
# Jermar Jefferson KTC data commited
# Jonathan Mingo KTC data commited
# Jordan Mason KTC data commited
# Garrett Wilson KTC data commited
# Josiah Deguara KTC data commited
# Julius Chestnut KTC data commited
# Justin Fields KTC data commited
# K.J. Hamler KTC data commited
# Justyn Ross KTC data commited
# Kavontae Turpin KTC data commited
# Kyler Murray KTC data commited
# Keaton Mitchell KTC data commited
# Keaontay Ingram KTC data commited
# Kellen Mond KTC data commited
# Kenneth Walker KTC data commited
# Kenny McIntosh KTC data commited
# Kenyan Drake KTC data commited
# Khalil Herbert KTC data commited
# Kyle Philips KTC data commited
# Kyle Trask KTC data commited
# Kyle Pitts KTC data commited
# Kylen Granson KTC data commited
# Kylin Hill KTC data commited
# Mac Jones KTC data commited
# Luke Schoonmaker KTC data commited
# Malik Heath KTC data commited
# Malik Willis KTC data commited
# Malik Cunningham KTC data commited
# Matt Corral KTC data commited
# Trevor Lawrence KTC data commited
# Mike Strachan KTC data commited
# Myles Gaskin KTC data commited
# Nick Westbrook-Ikhine KTC data commited
# Noah Gray KTC data commited
# Parris Campbell KTC data commited
# Qadree Ollison KTC data commited
# Quez Watkins KTC data commited
# Quintez Cephus KTC data commited
# Rakim Jarrett KTC data commited
# Raheem Blackshear KTC data commited
# Rashod Bateman KTC data commited
# Rashid Shaheed KTC data commited
# Error with Riley Patterson: list index out of range
# Ronnie Bell KTC data commited
# Ronnie Rivers KTC data commited
# Salvon Ahmed KTC data commited
# Sam LaPorta KTC data commited
# Sam Ehlinger KTC data commited
# Chris Olave KTC data commited
# Shi Smith KTC data commited
# Skylar Thompson KTC data commited
# Brock Purdy KTC data commited
# Tank Bigsby KTC data commited
# Tanner Hudson KTC data commited
# Tony Jones KTC data commited
# Travis Homer KTC data commited
# Trayveon Williams KTC data commited
# Drake London KTC data commited
# Tre' McKitty KTC data commited
# Trestan Ebner KTC data commited
# Trey McBride KTC data commited
# Trey Sermon KTC data commited
# Trey Palmer KTC data commited
# Tucker Kraft KTC data commited
# Tyler Allgeier KTC data commited
# Ty Chandler KTC data commited
# Tyler Badie KTC data commited
# Tylan Wallace KTC data commited
# Tutu Atwell KTC data commited
# Ty'Son Williams KTC data commited
# Tyler Johnson KTC data commited
# Tyler Huntley KTC data commited
# Tyquan Thornton KTC data commited
# Brandon Aiyuk KTC data commited
# Tyrion Davis-Price KTC data commited
# Will Mallory KTC data commited
# Xavier Gipson KTC data commited
# Zack Moss KTC data commited
# Zach Wilson KTC data commited
# Zamir White KTC data commited
# Tua Tagovailoa KTC data commited
# Travis Etienne KTC data commited
# Tank Dell KTC data commited
# Jonathan Taylor KTC data commited
# Tee Higgins KTC data commited
# Jaylen Waddle KTC data commited
# Jordan Addison KTC data commited
# Dalton Kincaid KTC data commited
# Nico Collins KTC data commited
# Zay Flowers KTC data commited
# Kyren Williams KTC data commited
# James Cook KTC data commited
# Rachaad White KTC data commited
# Jayden Reed KTC data commited
# Will Levis KTC data commited
# Christian Watson KTC data commited
# Tyjae Spears KTC data commited
# Zach Charbonnet KTC data commited
# Deebo Samuel KTC data commited
# David Montgomery KTC data commited
# Javonte Williams KTC data commited
# Josh Jacobs KTC data commited
# Marquise Brown KTC data commited
# Diontae Johnson KTC data commited
# Rhamondre Stevenson KTC data commited
# Isiah Pacheco KTC data commited
# Jake Ferguson KTC data commited
# Brian Robinson KTC data commited
# Bryce Young KTC data commited
# Rashee Rice KTC data commited
# Jameson Williams KTC data commited
# George Pickens KTC data commited
# Josh Downs KTC data commited
# Kendre Miller KTC data commited
# Jahan Dotson KTC data commited
# Quentin Johnston KTC data commited
# Chase Brown KTC data commited
# Marvin Mims KTC data commited
# Roschon Johnson KTC data commited
# Michael Mayer KTC data commited
# Devin Singletary KTC data commited
# Romeo Doubs KTC data commited
# Pat Freiermuth KTC data commited
# Josh Palmer KTC data commited
# Tony Pollard KTC data commited
# Jerry Jeudy KTC data commited
# Cole Kmet KTC data commited
# Darnell Mooney KTC data commited
# Daniel Jones KTC data commited
# Demario Douglas KTC data commited
# Gardner Minshew KTC data commited
# Michael Wilson KTC data commited
# Dontayvion Wicks KTC data commited
# Khalil Shakir KTC data commited
# Sam Howell KTC data commited
# Isaiah Likely KTC data commited
# Jerome Ford KTC data commited
# Luke Musgrave KTC data commited
# Jalin Hyatt KTC data commited
# Alec Pierce KTC data commited
# John Metchie KTC data commited
# Kenny Pickett KTC data commited
# Jelani Woods KTC data commited
# Trey Lance KTC data commited
# Antonio Gibson KTC data commited
# Drew Lock KTC data commited
# Dawson Knox KTC data commited
# Alexander Mattison KTC data commited
# Kenneth Gainwell KTC data commited
# Brevin Jordan KTC data commited
# Miles Sanders KTC data commited
# Noah Fant KTC data commited
# Elijah Moore KTC data commited
# Rondale Moore KTC data commited
# Chris Rodriguez KTC data commited
# Greg Dulcich KTC data commited
# Daniel Bellinger KTC data commited
# Hendon Hooker KTC data commited
# Juwan Johnson KTC data commited
# Andrei Iosivas KTC data commited
# Parker Washington KTC data commited
# Greg Dortch KTC data commited
# Xavier Hutchinson KTC data commited
# Skyy Moore KTC data commited
# Chigoziem Okonkwo KTC data commited
# Tre Tucker KTC data commited
# Dameon Pierce KTC data commited
# Rico Dowdle KTC data commited
# Treylon Burks KTC data commited
# Deuce Vaughn KTC data commited
# Cade Otton KTC data commited
# Kayshon Boutte KTC data commited
# Jeremy Ruckert KTC data commited
# Cameron Latu KTC data commited
# Mecole Hardman KTC data commited
# Terrace Marshall KTC data commited
# Chris Evans KTC data commited
# Darius Slayton KTC data commited
# Kadarius Toney KTC data commited
# Dyami Brown KTC data commited
# Marquez Callaway KTC data commited
# Denzel Mims KTC data commited
# Justice Hill KTC data commited
# Hassan Haskins KTC data commited
# Van Jefferson KTC data commited
# Justin Shorter KTC data commited
# David Bell KTC data commited
# Sean Tucker KTC data commited
# Ben Skowronek KTC data commited
# Colby Parkinson KTC data commited
# Emari Demercado KTC data commited
# Isaiah Hodgins KTC data commited
# Zach Evans KTC data commited
# Tommy Tremble KTC data commited
# Eric Gray KTC data commited
# Donald Parham KTC data commited
# Joshua Kelley KTC data commited
# Malik Davis KTC data commited
# Emanuel Wilson KTC data commited
# Jarrett Stidham KTC data commited
# Erik Ezukanma KTC data commited
# Hunter Long KTC data commited
# Jalen Nailor KTC data commited
# John Bates KTC data commited
# Sean Clifford KTC data commited
# Trenton Irwin KTC data commited
# Josh Allen KTC data commited
# A.J. Brown KTC data commited
# Ja'Marr Chase KTC data commited
# CeeDee Lamb KTC data commited
# Amon-Ra St. Brown KTC data commited
# Laviska Shenault KTC data commited
# Foster Moreau KTC data commited
# Stetson Bennett KTC data commited
# Chris Brooks KTC data commited
# Ty Johnson KTC data commited
# Tyson Bagent KTC data commited
# Clayton Tune KTC data commited
# Olamide Zaccheaus KTC data commited
# Hunter Renfrow KTC data commited
# Andrew Ogletree KTC data commited
# Jason Brownlee KTC data commited
# Kene Nwangwu KTC data commited
# Peyton Hendershot KTC data commited
# Wan'Dale Robinson KTC data commited
# Irv Smith KTC data commited
# Charlie Jones KTC data commited
# Kevin Harris KTC data commited
# Scott Miller KTC data commited
# D.J. Moore KTC data commited
# Jerick McKinnon KTC data commited
# T.J. Hockenson KTC data commited
# Lil'Jordan Humphrey KTC data commited
# DeAndre Hopkins KTC data commited
# JuJu Smith-Schuster KTC data commited
# Michael Pittman KTC data commited
# Michael Carter KTC data commited
# Clyde Edwards-Helaire KTC data commited
# DeVonta Smith KTC data commited
# J.K. Dobbins KTC data commited
# Terry McLaurin KTC data commited
# A.J. Dillon KTC data commited
# Najee Harris KTC data commited
# Tommy DeVito KTC data commited
# Cedric Tillman KTC data commited
# Bryce Ford-Wheaton KTC data commited
# Tyler Scott KTC data commited
# Aidan O'Connell KTC data commited
# Pierre Strong KTC data commited
# K.J. Osborn KTC data commited
# Ke'Shawn Vaughn KTC data commited
# Dorian Thompson-Robinson KTC data commited
# DeVante Parker KTC data commited
# Noah Brown KTC data commited
# Chase Edmonds KTC data commited
# Nelson Agholor KTC data commited
# David Njoku KTC data commited
# Justin Watson KTC data commited
# Dalton Schultz KTC data commited
# Corey Davis KTC data commited
# Zach Pascal KTC data commited
# Marquez Valdes-Scantling KTC data commited
# Darren Waller KTC data commited
# Nick Mullens KTC data commited
# Deshaun Watson KTC data commited
# Jamaal Williams KTC data commited
# Travis Kelce KTC data commited
# Marcus Mariota KTC data commited
# Mason Rudolph KTC data commited
# Michael Thomas KTC data commited
# Alvin Kamara KTC data commited
# Auden Tate KTC data commited
# Gerald Everett KTC data commited
# Dare Ogunbowale KTC data commited
# Kareem Hunt KTC data commited
# Courtland Sutton KTC data commited
# Jonnu Smith KTC data commited
# Will Dissly KTC data commited
# Josh Allen KTC data commited
# Jamal Agnew KTC data commited
# Marvin Jones KTC data commited
# Austin Hooper KTC data commited
# Mark Andrews KTC data commited
# Tyler Conklin KTC data commited
# D.J. Chark KTC data commited
# Isaiah McKenzie KTC data commited
# Carson Wentz KTC data commited
# Joe Mixon KTC data commited
# Kendrick Bourne KTC data commited
# Christian Kirk KTC data commited
# Aaron Jones KTC data commited
# Royce Freeman KTC data commited
# Stefon Diggs KTC data commited
# Byron Pringle KTC data commited
# Samaje Perine KTC data commited
# Zay Jones KTC data commited
# Odell Beckham KTC data commited
# Robert Woods KTC data commited
# Latavius Murray KTC data commited
# Russell Wilson KTC data commited
# Sony Michel KTC data commited
# Taysom Hill KTC data commited
# Keenan Allen KTC data commited
# Jameis Winston KTC data commited
# Adrian Peterson KTC data commited
# Darrel Williams KTC data commited
# George Kittle KTC data commited
# DeSean Jackson KTC data commited
# Cole Beasley KTC data commited
# Cooper Kupp KTC data commited
# Jared Goff KTC data commited
# Joshua Dobbs KTC data commited
# Mack Hollins KTC data commited
# Raheem Mostert KTC data commited
# Derek Carr KTC data commited
# John Brown KTC data commited
# Equanimeous St. Brown KTC data commited
# Gus Edwards KTC data commited
# Mike Gesicki KTC data commited
# Hayden Hurst KTC data commited
# Tyler Lockett KTC data commited
# Dontrell Hilliard KTC data commited
# Brandon Powell KTC data commited
# Adam Thielen KTC data commited
# Dallas Goedert KTC data commited
# Ezekiel Elliott KTC data commited
# Evan Engram KTC data commited
# Hunter Henry KTC data commited
# Josh Gordon KTC data commited
# Mike Williams KTC data commited
# Saquon Barkley KTC data commited
# Amari Cooper KTC data commited
# Matt Breida KTC data commited
# Christian McCaffrey KTC data commited
# Josh Reynolds KTC data commited
# Calvin Ridley KTC data commited
# Derrick Henry KTC data commited
# Tim Patrick KTC data commited
# Mike Evans KTC data commited
# Tyreek Hill KTC data commited
# Blake Jarwin KTC data commited
# Will Fuller KTC data commited
# Austin Ekeler KTC data commited
# Cordarrelle Patterson KTC data commited
# Nick Chubb KTC data commited
# Tyler Higbee KTC data commited
# Maxx Williams KTC data commited
# Nyheim Hines KTC data commited
# James Conner KTC data commited
# Baker Mayfield KTC data commited
# Tyrod Taylor KTC data commited
# Aaron Rodgers KTC data commited
# Davante Adams KTC data commited
# Lamar Jackson KTC data commited
# Marquise Goodwin KTC data commited
# D'Onta Foreman KTC data commited
# Demarcus Robinson KTC data commited
# Patrick Mahomes KTC data commited
# Zach Ertz KTC data commited
# Ryan Tannehill KTC data commited
# Curtis Samuel KTC data commited
# Allen Lazard KTC data commited
# Kirk Cousins KTC data commited
# Jimmy Garoppolo KTC data commited
# Taylor Heinicke KTC data commited
# Chris Godwin KTC data commited
# Kalif Raymond KTC data commited
# Cooper Rush KTC data commited
# Braxton Berrios KTC data commited
# Tyler Boyd KTC data commited
# Carlos Hyde KTC data commited
# Matt Ryan KTC data commited
# Jeffery Wilson KTC data commited
# Rob Gronkowski KTC data commited
# Geno Smith KTC data commited
# J.D. McKissic KTC data commited
# Jared Cook KTC data commited
# Brandin Cooks KTC data commited
# Brandon Bolden KTC data commited
# Derrius Guice KTC data commited
# Sam Darnold KTC data commited
# Matthew Stafford KTC data commited
# Dak Prescott KTC data commited
# Joe Flacco KTC data commited
# Boston Scott KTC data commited
# Michael Gallup KTC data commited
# Larry Roundtree KTC data commited
# Error with Frank Gore: list index out of range
# Brenden Rice KTC data commited
# Kimani Vidal KTC data commited
# Devontez Walker KTC data commited
# Bucky Irving KTC data commited
# Luke McCaffrey KTC data commited
# Ray Davis KTC data commited
# Theo Johnson KTC data commited
# Will Shipley KTC data commited
# Rasheen Ali KTC data commited
# Joe Milton KTC data commited
# Isaac Guerendo KTC data commited
# Audric Estime KTC data commited
# Scotty Miller KTC data commited
# Spencer Rattler KTC data commited
# KJ Hamler KTC data commited
# Malik Washington KTC data commited
# Tyrone Tracy KTC data commited
# Jared Wiley KTC data commited
# Javon Baker KTC data commited
# Louis Rees-Zammit KTC data commited
# Cade Stover KTC data commited
# Jalen McMillan KTC data commited
# Jarvis Landry KTC data commited
# Devonta Freeman KTC data commited
# Phillip Lindsay KTC data commited
# Mark Ingram KTC data commited
# Sterling Shepard KTC data commited
# Ronald Jones KTC data commited
# Sammy Watkins KTC data commited
# Anthony Firkser KTC data commited
# P.J. Walker KTC data commited
# Christopher Herndon KTC data commited
# Damien Williams KTC data commited
# Durham Smythe KTC data commited
# Mike White KTC data commited
# Robert Tonyan KTC data commited
# Richie James KTC data commited
# Tevin Coleman KTC data commited
# Tarik Cohen KTC data commited
# Tyrell Williams KTC data commited
# David Johnson KTC data commited
# T.Y. Hilton KTC data commited
# Russell Gage KTC data commited
# Rashaad Penny KTC data commited
# A.J. Green KTC data commited
# Colt McCoy KTC data commited
# Dan Arnold KTC data commited
# Teddy Bridgewater KTC data commited
# DeAndre Carter KTC data commited
# Marlon Mack KTC data commited
# Le'Veon Bell KTC data commited
# Ty Montgomery KTC data commited
# Devontae Booker KTC data commited
# Melvin Gordon KTC data commited
# Ameer Abdullah KTC data commited
# Emmanuel Sanders KTC data commited
# Trent Sherfield KTC data commited
# Case Keenum KTC data commited
# O.J. Howard KTC data commited
# Tre'Quan Smith KTC data commited
# Tom Brady KTC data commited
# Allen Robinson KTC data commited
# Randall Cobb KTC data commited
# Mitchell Trubisky KTC data commited
# Julian Edelman KTC data commited
# Antonio Brown KTC data commited
# Andy Dalton KTC data commited
# Logan Thomas KTC data commited
# Julio Jones KTC data commited
# Mo Alie-Cox KTC data commited
# Alex Collins KTC data commited
# Jamison Crowder KTC data commited
# C.J. Uzomah KTC data commited
# Rex Burkhead KTC data commited
# Peyton Barber KTC data commited
# Cam Newton KTC data commited
# Ricky Seals-Jones KTC data commited
# James Washington KTC data commited
# Justin Jackson KTC data commited
# Early 2024 1st KTC data commited
# Mid 2024 1st KTC data commited
# Late 2024 1st KTC data commited
# Early 2024 2nd KTC data commited
# Mid 2024 2nd KTC data commited
# Late 2024 2nd KTC data commited
# Early 2024 3rd KTC data commited
# Mid 2024 3rd KTC data commited
# Late 2024 3rd KTC data commited
# Early 2025 1st KTC data commited
# Mid 2025 1st KTC data commited
# Late 2025 1st KTC data commited
# Early 2025 2nd KTC data commited
# Mid 2025 2nd KTC data commited
# Late 2025 2nd KTC data commited
# Early 2025 3rd KTC data commited
# Mid 2025 3rd KTC data commited
# Early 2026 1st KTC data commited
# Mid 2026 1st KTC data commited
# Late 2026 1st KTC data commited
# Early 2026 2nd KTC data commited
# Mid 2026 2nd KTC data commited
# Late 2026 2nd KTC data commited
# Early 2026 3rd KTC data commited
# Mid 2026 3rd KTC data commited
# Late 2026 3rd KTC data commited
# Late 2025 3rd KTC data commited
# Josh Oliver KTC data commited
# Drake Maye KTC data commited
# Zach Charbonnet KTC data commited
# Jayden Daniels KTC data commited
# Dalton Kincaid KTC data commited
# Xavier Legette KTC data commited
# Will Levis KTC data commited
# Anthony Richardson KTC data commited
# Jaheim Bell KTC data commited
# Brock Bowers KTC data commited
# Brian Thomas KTC data commited
# Roschon Johnson KTC data commited
# Marvin Mims KTC data commited
# Michael Mayer KTC data commited
# Jahmyr Gibbs KTC data commited
# Josh Downs KTC data commited
# Marvin Harrison KTC data commited
# Ja'Lynn Polk KTC data commited
# Christian Watson KTC data commited
# Ja'Tavion Sanders KTC data commited
# Rome Odunze KTC data commited
# Adonai Mitchell KTC data commited
# Trey Benson KTC data commited
# Ricky Pearsall KTC data commited
# Michael Penix KTC data commited
# Alec Pierce KTC data commited
# Rachaad White KTC data commited
# Xavier Worthy KTC data commited
# Malik Nabers KTC data commited
# Jermaine Burton KTC data commited
# J.J. McCarthy KTC data commited
# Keon Coleman KTC data commited
# Kenny Pickett KTC data commited
# Kenneth Walker KTC data commited
# C.J. Stroud KTC data commited
# Blake Corum KTC data commited
# Ben Sinnott KTC data commited
# Quentin Johnston KTC data commited
# Troy Franklin KTC data commited
# Jalin Hyatt KTC data commited
# Jonathan Mingo KTC data commited
# Jayden Reed KTC data commited
# Jaylen Wright KTC data commited
# Jamari Thrash KTC data commited
# James Cook KTC data commited
# Tank Bigsby KTC data commited
# Caleb Williams KTC data commited
# Jelani Woods KTC data commited
# Jahan Dotson KTC data commited
# Roman Wilson KTC data commited
# Chase Brown KTC data commited
# Ladd McConkey KTC data commited
# Kendre Miller KTC data commited
# Bo Nix KTC data commited
# Jordan Addison KTC data commited
# Tyjae Spears KTC data commited
# Ryan Fitzpatrick KTC data commited
# MarShawn Lloyd KTC data commited
# Jonathon Brooks KTC data commited
# Trey McBride KTC data commited
# Mike Boone KTC data commited
# Kenny Golladay KTC data commited
# Chris Olave KTC data commited
# Mike Davis KTC data commited
# Malik Willis KTC data commited
# Giovani Bernard KTC data commited
# Wan'Dale Robinson KTC data commited
# Braelon Allen KTC data commited
# Leonard Fournette KTC data commited
# Breshad Perriman KTC data commited
# Malachi Corley KTC data commited
# Zonovan Knight KTC data commited
# [<models.Player at 0x1b75cf5a020>, <models.Player at 0x1b75cfa2200>]
